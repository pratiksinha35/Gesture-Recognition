# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#!unzip /content/drive/MyDrive/Project_data.zip

# %%
import numpy as np
import os
from cv2 import imread, resize
import datetime
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
os.environ['PYTHONHASHSEED']="30"
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5)  # count for loading folders for 5 classes
    train_data = []
    val_data = []

    # when ablation is None, pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            label = int(doc.strip().split(';')[2])
            if counts[label] < ablation:
                train_data.append(doc)
                counts[label] += 1

        counts = np.zeros(5)

        # iterating val doc
        for doc in val_doc:
            label = int(doc.strip().split(';')[2])
            if counts[label] < ablation:
                val_data.append(doc)
                counts[label] += 1
    else:
        train_data, val_data = train_doc, val_doc

    return train_data, val_data

# %%
# # train and validatiaon data creator with ablation
# # when ablation is 10, then 10 folders for each label will be selected.
# def get_data(path, ablation=None):
#     train_doc = np.random.permutation(open(path+'train.csv').readlines())
#     val_doc = np.random.permutation(open(path+'val.csv').readlines())
#     counts = np.zeros(5) # count for loading folders for 5 classes
#     train_data = []
#     val_data = []
#     # when ablation is None pass full training and val data
#     if ablation is not None:
#         # iterating train doc
#         for doc in train_doc:
#             lable = int(doc.strip().split(';')[2])
#             if counts[lable] < ablation:
#                 train_data.append(doc)
#                 counts[lable] += 1
#         counts = np.zeros(5)
#         # iterating val doc
#         for doc in val_doc:
#             lable = int(doc.strip().split(';')[2])
#             if counts[lable] < ablation:
#                 val_data.append(doc)
#                 counts[lable] += 1
#     else:
#         train_data, val_data = train_doc, val_doc
#     return train_data, val_data

# %%
train_doc, val_doc = get_data('Project_data/', ablation=None)
batch_size = 32 # experiment with the batch size
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# def generator(source_path, folder_list, batch_size):
#     print( 'Source path = ', source_path, '; batch size =', batch_size)
#     img_idx = seq_idx#create a list of image numbers you want to use for a particular video
#     x = len(img_idx)
#     y = dim_x
#     z = dim_y
#     while True:
#         t = np.random.permutation(folder_list)
#         num_batches = len(source_path)//batch_size # calculate the number of batches
#         for batch in range(num_batches): # we iterate over the number of batches
#             batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
#             batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
#             for folder in range(batch_size): # iterate over the batch_size
#                 imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
#                 for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
#                     image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)



#                     # Cropped image of above dimension
#                     # (It will not change orginal image)

#                     #image = image.crop((0, 0, 120, 120))
#                     image = resize(image, (dim_x, dim_y))


#                     #crop the images and resize them. Note that the images are of 2 different shape
#                     #and the conv3D will throw error if the inputs in a batch have different shapes

#                     batch_data[folder, idx, :, :, 0] = image[:, :, 0] / 255
#                     batch_data[folder, idx, :, :, 1] = image[:, :, 1] / 255
#                     batch_data[folder, idx, :, :, 2] = image[:, :, 2] / 255

#                 batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
#             yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do


#         # write the code for the remaining data points which are left after full batches
#         if((len(source_path)%batch_size)//2==0):
#             batch_size = 2
#         else:
#             batch_size = 1
#         num_batches = len(source_path)%batch_size # calculate the number of batches
#         for batch in range(num_batches): # we iterate over the number of batches
#             batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
#             batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
#             for folder in range(batch_size): # iterate over the batch_size
#                 imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
#                 for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
#                     image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)



#                     # Cropped image of above dimension
#                     # (It will not change orginal image)

#                     #image = image.crop((0, 0, 120, 120))
#                     image = resize(image, (dim_x, dim_y))


#                     #crop the images and resize them. Note that the images are of 2 different shape
#                     #and the conv3D will throw error if the inputs in a batch have different shapes

#                     batch_data[folder, idx, :, :, 0] = image[:, :, 0] / 255
#                     batch_data[folder, idx, :, :, 1] = image[:, :, 1] / 255
#                     batch_data[folder, idx, :, :, 2] = image[:, :, 2] / 255

#                 batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
#             yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %%
# generator without augmentation and cropping for train data
def generator(source_path, folder_list, batch_size):
    img_idx = seq_idx  # create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        t = np.random.permutation(folder_list)

        if (len(t) % batch_size) == 0:
            num_batches = int(len(t) / batch_size)
        else:
            num_batches = len(t) // batch_size + 1

        for batch in range(num_batches):  # we iterate over the number of batches
            batch_data = np.zeros((batch_size, x, y, z, 3))  # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size, 5))  # batch_labels is the one hot representation of the output
            for folder in range(batch_size):  # iterate over the batch_size
                # handling remaining datapoints
                folder_idx = folder + (batch * batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path + '/' + folder_str.split(';')[0])  # read all the images in the folder

                for idx, item in enumerate(img_idx):  # Iterate over the frames/images of a folder to read them in
                    image = imread(source_path + '/' + folder_str.strip().split(';')[0] + '/' + imgs[item]).astype(
                        np.float32)

                    # resize the images. Note that the images are of 2 different shapes
                    # and the conv3D will throw an error if the inputs in a batch have different shapes
                    resized_im = resize(image, dsize=(y, z))

                    # normalise and feed in the image
                    batch_data[folder, idx, :, :, 0] = resized_im[:, :, 0] / 255
                    batch_data[folder, idx, :, :, 1] = resized_im[:, :, 1] / 255
                    batch_data[folder, idx, :, :, 2] = resized_im[:, :, 2] / 255

                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1
            yield batch_data, batch_labels  # you yield the batch_data and the batch_labels

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'Project_data/train' #'/notebooks/storage/Final_data/Collated_training/train'
val_path =  'Project_data/val' #'/notebooks/storage/Final_data/Collated_training/val'

num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 30 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 30

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D, Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# # Final Model

# %%
# model = Sequential()
# model.add(Conv3D(32, kernel_size=(3, 3, 3), activation='relu', input_shape=input_shape))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(Flatten())
# model.add(Dense(128, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %%
# model = Sequential()
# model.add(Conv3D(32, kernel_size=(3, 3, 3), activation='relu', input_shape=input_shape))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(Conv3D(64, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 8, 118, 118, 32)   2624
#
#  max_pooling3d (MaxPooling3D  (None, 4, 59, 59, 32)    0
#  )
#
#  flatten (Flatten)           (None, 445568)            0
#
#  dense (Dense)               (None, 128)               57032832
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 57,036,101
# Trainable params: 57,036,101
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
from keras.callbacks import EarlyStopping

model_name = 'gesture_recognition_conv3d_batch_size_32' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here

earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)

callbacks_list = [checkpoint, LR, earlystop]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                        callbacks=callbacks_list, validation_data=val_generator,
                        validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 414.1875 - categorical_accuracy: 0.3672
# Epoch 1: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00001-414.18750-0.36719-4.09986-0.18750.h5
# 4/4 [==============================] - 113s 30s/step - loss: 414.1875 - categorical_accuracy: 0.3672 - val_loss: 4.0999 - val_categorical_accuracy: 0.1875 - lr: 0.0100
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 1.7368 - categorical_accuracy: 0.1953
# Epoch 2: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00002-1.73678-0.19531-1.57821-0.21875.h5
# 4/4 [==============================] - 105s 28s/step - loss: 1.7368 - categorical_accuracy: 0.1953 - val_loss: 1.5782 - val_categorical_accuracy: 0.2188 - lr: 0.0100
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 1.2589 - categorical_accuracy: 0.1562
# Epoch 3: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00003-1.25891-0.15625-1.57668-0.21875.h5
# 4/4 [==============================] - 104s 28s/step - loss: 1.2589 - categorical_accuracy: 0.1562 - val_loss: 1.5767 - val_categorical_accuracy: 0.2188 - lr: 0.0100
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 1.2588 - categorical_accuracy: 0.1562
# Epoch 4: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00004-1.25885-0.15625-1.57779-0.20833.h5
# 4/4 [==============================] - 101s 27s/step - loss: 1.2588 - categorical_accuracy: 0.1562 - val_loss: 1.5778 - val_categorical_accuracy: 0.2083 - lr: 0.0100
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 1.2588 - categorical_accuracy: 0.1562
# Epoch 5: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00005-1.25879-0.15625-1.57705-0.18750.h5
# 4/4 [==============================] - 106s 28s/step - loss: 1.2588 - categorical_accuracy: 0.1562 - val_loss: 1.5771 - val_categorical_accuracy: 0.1875 - lr: 0.0100
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 1.
saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00006-1.26928-0.14062-1.59182-0.20833.h5
# 4/4 [==============================] - 113s 30s/step - loss: 1.2693 - categorical_accuracy: 0.1406 - val_loss: 1.5918 - val_categorical_accuracy: 0.2083 - lr: 0.0100
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 1.2622 - categorical_accuracy: 0.1641
# Epoch 7: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00007-1.26220-0.16406-1.58790-0.18750.h5
# 4/4 [==============================] - 111s 29s/step - loss: 1.2622 - categorical_accuracy: 0.1641 - val_loss: 1.5879 - val_categorical_accuracy: 0.1875 - lr: 0.0100
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 1.2672 - categorical_accuracy: 0.1484
# Epoch 8: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00008-1.26718-0.14844-1.57982-0.20833.h5
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 4/4 [==============================] - 111s 30s/step - loss: 1.2672 - categorical_accuracy: 0.1484 - val_loss: 1.5798 - val_categorical_accuracy: 0.2083 - lr: 0.0100
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 1.2573 - categorical_accuracy: 0.1406
# Epoch 9: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00009-1.25726-0.14062-1.57562-0.19792.h5
# 4/4 [==============================] - 110s 29s/step - loss: 1.2573 - categorical_accuracy: 0.1406 - val_loss: 1.5756 - val_categorical_accuracy: 0.1979 - lr: 0.0020
# Epoch 10/20
# 4/4 [==============================] - ETA: 0s - loss: 1.2581 - categorical_accuracy: 0.1953
# Epoch 10: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00010-1.25807-0.19531-1.58475-0.18750.h5
# 4/4 [==============================] - 110s 29s/step - loss: 1.2581 - categorical_accuracy: 0.1953 - val_loss: 1.5848 - val_categorical_accuracy: 0.1875 - lr: 0.0020
# Epoch 11/20
# 4/4 [==============================] - ETA: 0s - loss: 1.2620 - categorical_accuracy: 0.1328
# Epoch 11: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00011-1.26198-0.13281-1.57920-0.20833.h5
# 4/4 [==============================] - 110s 29s/step - loss: 1.2620 - categorical_accuracy: 0.1328 - val_loss: 1.5792 - val_categorical_accuracy: 0.2083 - lr: 0.0020
# Epoch 12/20
# 4/4 [==============================] - ETA: 0s - loss: 1.2627 - categorical_accuracy: 0.1562
# Epoch 12: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00012-1.26273-0.15625-1.59110-0.16667.h5
# 4/4 [==============================] - 110s 29s/step - loss: 1.2627 - categorical_accuracy: 0.1562 - val_loss: 1.5911 - val_categorical_accuracy: 0.1667 - lr: 0.0020
# Epoch 13/20
# 4/4 [==============================] - ETA: 0s - loss: 1.2631 - categorical_accuracy: 0.1562
# Epoch 13: saving model to gesture_recognition_conv3d_batch_size_32_2024-02-2916_34_01.394090/model-00013-1.26314-0.15625-1.57396-0.20833.h5
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.001.
# 4/4 [==============================] - 110s 29s/step - loss: 1.2631 - categorical_accuracy: 0.1562 - val_loss: 1.5740 - val_categorical_accuracy: 0.2083 - lr: 0.0020
# Epoch 13: early stopping

# %%
# plt.figure(figsize=(20,6))
# ax1 = plt.subplot(121)
# ax1 = plt.plot(history.history['loss'])
# ax1 = plt.plot(history.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'validation'], loc='lower left')
# ax2 = plt.subplot(122)
# ax2 = plt.plot(history.history['categorical_accuracy'])
# ax2 = plt.plot(history.history['val_categorical_accuracy'])
# plt.title('model accuracy')
# plt.ylabel('categorical_accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'validation'], loc='lower left')

# %%
model = Sequential()

model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))

model.add(Conv3D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %%
optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_6 (Conv3D)           (None, 8, 118, 118, 32)   2624
#
#  conv3d_7 (Conv3D)           (None, 6, 116, 116, 64)   55360
#
#  max_pooling3d_4 (MaxPoolin  (None, 3, 58, 58, 64)     0
#  g3D)
#
#  conv3d_8 (Conv3D)           (None, 1, 56, 56, 128)    221312
#
#  max_pooling3d_5 (MaxPoolin  (None, 1, 28, 28, 128)    0
#  g3D)
#
#  conv3d_9 (Conv3D)           (None, 1, 26, 26, 256)    295168
#
#  max_pooling3d_6 (MaxPoolin  (None, 1, 13, 13, 256)    0
#  g3D)
#
#  conv3d_10 (Conv3D)          (None, 1, 11, 11, 512)    1180160
#
#  conv3d_11 (Conv3D)          (None, 1, 9, 9, 512)      2359808
#
#  max_pooling3d_7 (MaxPoolin  (None, 1, 4, 4, 512)      0
#  g3D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 512)               4194816
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params:
None, 6, 116, 116, 64)   55360
#
#  max_pooling3d_8 (MaxPoolin  (None, 3, 58, 58, 64)     0
#  g3D)
#
#  batch_normalization (Batch  (None, 3, 58, 58, 64)     256
#  Normalization)
#
#  conv3d_14 (Conv3D)          (None, 1, 56, 56, 128)    221312
#
#  max_pooling3d_9 (MaxPoolin  (None, 1, 28, 28, 128)    0
#  g3D)
#
#  batch_normalization_1 (Bat  (None, 1, 28, 28, 128)    512
#  chNormalization)
#
#  conv3d_15 (Conv3D)          (None, 1, 26, 26, 256)    295168
#
#  max_pooling3d_10 (MaxPooli  (None, 1, 13, 13, 256)    0
#  ng3D)
#
#  batch_normalization_2 (Bat  (None, 1, 13, 13, 256)    1024
#  chNormalization)
#
#  conv3d_16 (Conv3D)          (None, 1, 11, 11, 512)    1180160
#
#  conv3d_17 (Conv3D)          (None, 1, 9, 9, 512)      2359808
#
#  max_pooling3d_11 (MaxPooli  (None, 1, 4, 4, 512)      0
#  ng3D)
#
#  batch_normalization_3 (Bat  (None, 1, 4, 4, 512)      2048
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 512)               4194816
#
#  batch_normalization_4 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_3 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 8317701 (31.73 MB)
# Trainable params: 8314757 (31.72 MB)
# Non-trainable params: 2944 (11.50 KB)
# _________________________________________________________________
# None

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                        callbacks=callbacks_list, validation_data=val_generator,
                        validation_steps=validation_steps, class_weight=None, workers=-1, initial_epoch=0)
# Out:
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 2.9077 - categorical_accuracy: 0.3125
# Epoch 1: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00001-2.90771-0.31250-2.62590-0.21875.h5
# 4/4 [==============================] - 153s 38s/step - loss: 2.9077 - categorical_accuracy: 0.3125 - val_loss: 2.6259 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 1.5363 - categorical_accuracy: 0.4844
# Epoch 2: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00002-1.53629-0.48438-8.29389-0.27083.h5
# 4/4 [==============================] - 152s 39s/step - loss: 1.5363 - categorical_accuracy: 0.4844 - val_loss: 8.2939 - val_categorical_accuracy: 0.2708 - lr: 0.0010
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 0.8078 - categorical_accuracy: 0.5938
# Epoch 3: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00003-0.80783-0.59375-10.45786-0.21875.h5
# 4/4 [==============================] - 150s 38s/step - loss: 0.8078 - categorical_accuracy: 0.5938 - val_loss: 10.4579 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 0.4511 - categorical_accuracy: 0.6250
# Epoch 4: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00004-0.45107-0.62500-11.95194-0.21875.h5
# 4/4 [==============================] - 151s 38s/step - loss: 0.4511 - categorical_accuracy: 0.6250 - val_loss: 11.9519 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2161 - categorical_accuracy: 0.7422
# Epoch 5: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00005-0.21607-0.74219-12.91928-0.32292.h5
# 4/4 [==============================] - 151s 38s/step - loss: 0.2161 - categorical_accuracy: 0.7422 - val_loss: 12.9193 - val_categorical_accuracy: 0.3229 - lr: 0.0010
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2010 - categorical_accuracy: 0.7344
# Epoch 6: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00006-0.20100-0.73438-13.42946-0.22917.h5
# 4/4 [==============================] - 151s 38s/step - loss: 0.2010 - categorical_accuracy: 0.7344 - val_loss: 13.4295 - val_categorical_accuracy: 0.2292 - lr: 0.0010
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0838 - categorical_accuracy: 0.7734
# Epoch 7: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00007-0.08378-0.77344-9.46163-0.17708.h5
# 4/4 [==============================] - 150s 38s/step - loss: 0.0838 - categorical_accuracy: 0.7734 - val_loss: 9.4616 - val_categorical_accuracy: 0.1771 - lr: 0.0010
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0531 - categorical_accuracy: 0.7734
# Epoch 8: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00008-0.05313-0.77344-6.10051-0.22917.h5
# 4/4 [==============================] - 152s 39s/step - loss: 0.0531 - categorical_accuracy: 0.7734 - val_loss: 6.1005 - val_categorical_accuracy: 0.2292 - lr: 0.0010
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1226 - categorical_accuracy: 0.7656
# Epoch 9: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00009-0.12259-0.76562-4.89204-0.23958.h5
# 4/4 [==============================] - 150s 38s/step - loss: 0


model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
#model.add(Dropout(0.2))
model.add(Dropout(0.5))

model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
#model.add(Dropout(0.2))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %%
optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_18 (Conv3D)          (None, 8, 118, 118, 32)   2624
#
#  conv3d_19 (Conv3D)          (None, 6, 116, 116, 64)   55360
#
#  max_pooling3d_12 (MaxPooli  (None, 3, 58, 58, 64)     0
#  ng3D)
#
#  batch_normalization_5 (Bat  (None, 3, 58, 58, 64)     256
#  chNormalization)
#
#  dropout (Dropout)           (None, 3, 58, 58, 64)     0
#
#  conv3d_20 (Conv3D)          (None, 1, 56, 56, 128)    221312
#
#  max_pooling3d_13 (MaxPooli  (None, 1, 28, 28, 128)    0
#  ng3D)
#
#  batch_normalization_6 (Bat  (None, 1, 28, 28, 128)    512
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 1, 28, 28, 128)    0
#
#  conv3d_21 (Conv3D)          (None, 1, 26, 26, 256)    295168
#
#  max_pooling3d_14 (MaxPooli  (None, 1, 13, 13, 256)    0
#  ng3D)
#
#  batch_normalization_7 (Bat  (None, 1, 13, 13, 256)    1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 1, 13, 13, 256)    0
#
#  conv3d_22 (Conv3D)          (None, 1, 11, 11, 512)    1180160
#
#  conv3d_23 (Conv3D)          (None, 1, 9, 9, 512)      2359808
#
#  max_pooling3d_15 (MaxPooli  (None, 1, 4, 4, 512)      0
#  ng3D)
#
#  batch_normalization_8 (Bat  (None, 1, 4, 4, 512)      2048
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 1, 4, 4, 512)      0
#
#  flatten_2 (Flatten)         (None, 8192)              0
#
#  dense_4 (Dense)             (None, 512)               4194816
#
#  batch_normalization_9 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_5 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 8317701 (31.73 MB)
# Trainable params: 8314757 (31.72 MB)
# Non-trainable params: 2944 (11.50 KB)
# _________________________________________________________________
# None

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                        callbacks=callbacks_list, validation_data=val_generator,
                        validation_steps=validation_steps, class_weight=None, workers=-1, initial_epoch=0)
# Out:
# Epoch 1/30
# 4/4 [==============================] - ETA: 0s - loss: 2.3041 - categorical_accuracy: 0.3438
# Epoch 1: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00001-2.30411-0.34375-1.78690-0.23958.h5
# 4/4 [==============================] - 154s 38s/step - loss: 2.3041 - categorical_accuracy: 0.3438 - val_loss: 1.7869 - val_categorical_accuracy: 0.2396 - lr: 0.0010
# Epoch 2/30
# 4/4 [==============================] - ETA: 0s - loss: 2.8551 - categorical_accuracy: 0.3203
# Epoch 2: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00002-2.85515-0.32031-2.61060-0.25000.h5
# 4/4 [==============================] - 151s 39s/step - loss: 2.8551 - categorical_accuracy: 0.3203 - val_loss: 2.6106 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 3/30
# 4/4 [==============================] - ETA: 0s - loss: 2.3083 - categorical_accuracy: 0.4219
# Epoch 3: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00003-2.30835-0.42188-7.98330-0.21875.h5
# 4/4 [==============================] - 152s 39s/step - loss: 2.3083 - categorical_accuracy: 0.4219 - val_loss: 7.9833 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# Epoch 4/30
# 4/4 [==============================] - ETA: 0s - loss: 1.6200 - categorical_accuracy: 0.5078
# Epoch 4: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00004-1.62004-0.50781-13.01470-0.23958.h5
# 4/4 [==============================] - 155s 39s/step - loss: 1.6200 - categorical_accuracy: 0.5078 - val_loss: 13.0147 - val_categorical_accuracy: 0.2396 - lr: 0.0010
# Epoch 5/30
# 4/4 [==============================] - ETA: 0s - loss: 1.8985 - categorical_accuracy: 0.3906
# Epoch 5: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00005-1.89853-0.39062-10.95243-0.16667.h5
# 4/4 [==============================] - 151s 39s/step - loss: 1.8985 - categorical_accuracy: 0.3906 - val_loss: 10.9524 - val_categorical_accuracy: 0.1667 - lr: 0.0010
# Epoch 6/30
# 4/4 [==============================] - ETA: 0s - loss: 1.6532 - categorical_accuracy: 0.4453
# Epoch 6: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00006-1.65321-0.44531-5.59352-0.22917.h5
# 4/4 [==============================] - 151s 38s/step - loss: 1.6532 - categorical_accuracy: 0.4453 - val_loss: 5.5935 - val_categorical_accuracy: 0.2292 - lr: 0.0010
# Epoch 7/30
# 4/4 [==============================] - ETA: 0s - loss: 1.4617 - categorical_accuracy: 0.4375
# Epoch 7: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00007-1.46168-0.43750-8.12124-0.23958.h5
# 4/4 [==============================] - 151s 38s/step - loss: 1.4617 - categorical_accuracy: 0.4375 - val_loss: 8.1212 - val_categorical_accuracy: 0.2396 - lr: 0.0010
# Epoch 8/30
# 4/4 [==============================] - ETA: 0s - loss: 1.2820 - categorical_accuracy: 0.5156
# Epoch 8: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00008-1.28200-0.51562-10.04871-0.23958.h5
# 4/4 [==============================] - 154s 39s/step - loss: 1.2820 - categorical_accuracy: 0.5156 - val_loss: 10.0487 - val_categorical_accuracy: 0.2396 - lr: 0.0010
# Epoch 9/30
# 4/4 [==============================] - ETA: 0s - loss: 1.0820 - categorical_accuracy: 0.5781
# Epoch 9: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00009-1.08200-0.57812-8.68389-0.23958.h5
# 4/4 [==============================] - 156s 40s/step - loss: 1.0820 - categorical_accuracy: 0.5781 - val_loss: 8.6839 - val_categorical_accuracy: 0.2396 - lr: 0.0010
# Epoch 10/30
# 4/4 [==============================] - ETA: 0s - loss: 1.1232 - categorical_accuracy: 0.5547
# Epoch 10: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00010-1.12323-0.55469-5.39179-0.21875.h5
# 4/4 [==============================] - 153s 39s/step - loss: 1.1232 - categorical_accuracy: 0.5547 - val_loss: 5.3918 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# Epoch 11/30
# 4/4 [==============================] - ETA: 0s - loss: 0.9586 - categorical_accuracy: 0.6797
# Epoch 11: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00011-0.95864-0.67969-5.24059-0.17708.h5
# 4/4 [==============================] - 151s 39s/step - loss: 0.9586 - categorical_accuracy: 0.6797 - val_loss: 5.2406 - val_categorical_accuracy: 0.1771 - lr: 0.0010
# Epoch 11: early stopping

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')

# %%
model = Sequential()

model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv3D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(GlobalAveragePooling3D())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %%
optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_28 (Conv3D)          (None, 8, 118, 118, 32)   2624
#
#  conv3d_29 (Conv3D)          (None, 6, 116, 116, 64)   55360
#
#  max_pooling3d_19 (MaxPooli  (None, 3, 58, 58, 64)     0
#  ng3D)
#
#  batch_normalization_14 (Ba  (None, 3, 58, 58, 64)     256
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 3, 58, 58, 64)     0
#
#  conv3d_30 (Conv3D)          (None, 1, 56, 56, 128)    221312
#
#  max_pooling3d_20 (MaxPooli  (None, 1, 28, 28, 128)    0
#  ng3D)
#
#  batch_normalization_15 (Ba  (None, 1, 28, 28, 128)    512
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 1, 28, 28, 128)    0
#
#  conv3d_31 (Conv3D)          (None, 1, 26, 26, 256)    295168
#
#  max_pooling3d_21 (MaxPooli  (None, 1, 13, 13, 256)    0
#  ng3D)
#
#  batch_normalization_16 (Ba  (None, 1, 13, 13, 256)    1024
#  tchNormalization)
#
#  dropout_9 (Dropout)         (None, 1, 13, 13, 256)    0
#
#  global_average_pooling3d_1  (None, 256)               0
#   (GlobalAveragePooling3D)
#
#  dense_8 (Dense)             (None, 512)               131584
#
#  batch_normalization_17 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense_9 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 712453 (2.72 MB)
# Trainable params: 710533 (2.71 MB)
# Non-trainable params: 1920 (7.50 KB)
# _________________________________________________________________
# None

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                        callbacks=callbacks_list, validation_data=val_generator,
                        validation_steps=validation_steps, class_weight=None, workers=-1, initial_epoch=0)
# Out:
# Epoch 1/30
# 4/4 [==============================] - ETA: 0s - loss: 1.9968 - categorical_accuracy: 0.3125
# Epoch 1: saving model to gesture_recognition_conv3d_batch_size_32_2024-03-0114_36_07.092372\model-00001-1.99679-0.31250-1.58960-0.23958.h5
# 4/4 [==============================] - 149s 37s/step - loss: 1.9968 - categorical_accuracy: 0.3125 - val_loss: 1.5896 - val_categorical_accuracy: 0.2396 - lr: 0.0010
# Epoch