# %% [markdown]
# # Gesture Recognition
#
# In this project, we are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.
#
# Problem Statement
# Imagine we are working as a data scientist at a home electronics company which manufactures state of the art smart televisions. We want to develop a cool feature in the smart-TV that can recognise five different gestures performed by the user which will help users control the TV without using a remote.
# The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
#
# - Thumbs up:  Increase the volume
# - Thumbs down: Decrease the volume
# - Left swipe: 'Jump' backwards 10 seconds
# - Right swipe: 'Jump' forward 10 seconds
# - Stop: Pause the movie
#
#
# Each video is a sequence of 30 frames (or images).

# %%
import numpy as np
import os
import imageio
from skimage.transform import resize, rescale
import datetime
import os

import matplotlib.pyplot as plt

from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, GRU, LSTM, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.regularizers import l2
from keras import optimizers

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
import tensorflow as tf
print(tf.__version__)
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
tf.random.set_seed(30)
# Out:
# 2.10.1

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open(r'Project_data\train.csv').readlines())
val_doc = np.random.permutation(open(r'Project_data\val.csv').readlines())
num_classes = 5  #number of softmax classes

# %%
curr_dt_time = datetime.datetime.now()
train_path = r'Project_data\train'
val_path = r'Project_data\val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
# Out:
# # training sequences = 663
# # validation sequences = 100

# %% [markdown]
# ## Common Utils

# %% [markdown]
# Common utility to plot loss and accuracy

# %%
def plot_loss_accuracy(history):
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['categorical_accuracy'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %% [markdown]
# Common utility to calculate steps

# %%
def calculate_steps(num_train_sequences, num_val_sequences, batch_size):
    if (num_train_sequences%batch_size) == 0:
        steps_per_epoch = int(num_train_sequences/batch_size)
    else:
        steps_per_epoch = (num_train_sequences//batch_size) + 1

    if (num_val_sequences%batch_size) == 0:
        validation_steps = int(num_val_sequences/batch_size)
    else:
        validation_steps = (num_val_sequences//batch_size) + 1

    return steps_per_epoch,validation_steps

# %% [markdown]
# Common utility for callbacks

# %%
def model_callbacks(folder_name):
    model_name = str(folder_name) + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
   
    if not os.path.exists(model_name):
        os.mkdir(model_name)

    filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

    LR = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=0.0001, cooldown=1, verbose=1) # write the REducelronplateau code here

    return [checkpoint, LR]

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, we are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. we have to experiment with `img_idx`, `y`,`z` and normalization such that we get high accuracy.

# %%
from keras.preprocessing.image import ImageDataGenerator
#from keras.preprocessing.image import smart_resize

datagen = ImageDataGenerator(
    zoom_range=0.1,
    zca_whitening=True,
    width_shift_range=0.1,
    height_shift_range=0.1)

## Test code start
#360 by 360
image1 = imageio.imread(r"Project_data\train\WIN_20180907_15_35_09_Pro_Right Swipe_new\WIN_20180907_15_35_09_Pro_00012.png")
#160 by 120
image2 = imageio.imread(r"Project_data\train\WIN_20180907_15_35_09_Pro_Right Swipe_new\WIN_20180907_15_35_09_Pro_00014.png")
#crop the images and resize them. Note that the images are of 2 different shape 
#and the conv3D will throw error if the inputs in a batch have different shapes                    
#print(image1.shape, image2.shape)
image1 = resize(image1, (120, 120), anti_aliasing=True)
image1 = datagen.random_transform(image1)                   
plt.imshow(image1)
plt.show()
image2 = resize(image2, (120, 120), anti_aliasing=True)
image2 = datagen.random_transform(image2)                 
plt.imshow(image2)
plt.show()
## Test code end

def generate(source_path, folder_list, batch_size, num_images=20, height=120, width=120, augment=False):
    #print( 'Source path = ', source_path, '; batch size =', batch_size)
    total_frames = 30

    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size # calculate the number of batches
        #img_idx = sorted(rn.sample(range(0, total_frames), num_images)) #create a list of image numbers you want to use for a particular video
        img_idx = np.round(np.linspace(0,total_frames-1,num_images)).astype(int) #create a list of image numbers you want to use for a particular video

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data   = np.zeros((batch_size, num_images, height, width, 3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size, 5)) # batch_labels is the one hot representation of the output           

            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes                    
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)

                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)                   

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image                  
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
        
        # write the code for the remaining data points which are left after full batches
        if (len(t)%batch_size):
            remaining_batch_size = len(t)%batch_size
            batch_data   = np.zeros((remaining_batch_size, num_images, height, width,3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((remaining_batch_size,5)) # batch_labels is the one hot representation of the output           

            for folder in range(remaining_batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)                          
                    
                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)                   

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image
                   
                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
# Out:
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:12: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image1 = imageio.imread(r"Project_data\train\WIN_20180907_15_35_09_Pro_Right Swipe_new\WIN_20180907_15_35_09_Pro_00012.png")
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:14: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image2 = imageio.imread(r"Project_data\train\WIN_20180907_15_35_09_Pro_Right Swipe_new\WIN_20180907_15_35_09_Pro_00014.png")

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %% [markdown]
# ## Model
# Here we make the model using different functionalities that Keras provides. We will use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. We would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. We will Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, GRU, LSTM, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.regularizers import l2
from keras import optimizers

# %% [markdown]
# ### Conv3d Models

# %%
# Common utility to create conv 3D models
def conv3D(conv_filters=(16, 32, 64, 128), dense_nodes=(256,128), dropout=0.25, num_images=20, height=120, width=120):

    model = Sequential()

    model.add(Conv3D(conv_filters[0], (3, 3, 3), padding='same', input_shape=(num_images, height, width, 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(conv_filters[1], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[2], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[3], (3, 3, 3), padding='same'))    
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Flatten())
    model.add(Dense(dense_nodes[0]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(dense_nodes[1]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    opt = tf.keras.optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    
    return model

# %% [markdown]
# #### Model 1: Conv 3D Model with 30 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 30, 120, 120, 16)  1312
#
#  activation_7 (Activation)   (None, 30, 120, 120, 16)  0
#
#  batch_normalization_6 (Batc  (None, 30, 120, 120, 16)  64
#  hNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 15, 60, 60, 16)   0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 15, 60, 60, 32)    13856
#
#  activation_8 (Activation)   (None, 15, 60, 60, 32)    0
#
#  batch_normalization_7 (Batc  (None, 15, 60, 60, 32)   128
#  hNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 7, 30, 30, 32)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 7, 30, 30, 64)     55360
#
#  activation_9 (Activation)   (None, 7, 30, 30, 64)     0
#
#  batch_normalization_8 (Batc  (None, 7, 30, 30, 64)    256
#  hNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 3, 15, 15, 64)    0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 3, 15, 15, 128)    221312
#
#  activation_10 (Activation)  (None, 3, 15, 15, 128)    0
#
#  batch_normalization_9 (Batc  (None, 3, 15, 15, 128)   512
#  hNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_3 (Dense)             (None, 256)               1605888
#
#  activation_11 (Activation)  (None, 256)               0
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  activation_12 (Activation)  (None, 128)               0
#
#  batch_normalization_11 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 5)                 645
#
#  activation_13 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 1,933,765
# Trainable params: 1,932,517
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_1")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                             callbacks=callbacks_list, validation_data=val_generator, 
                             validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 [============================>.] - ETA: 5s - loss: 1.5346 - categorical_accuracy: 0.4292
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1.5334 - categorical_accuracy: 0.4299
# Epoch 1: val_loss improved from inf to 3.02183, saving model to model_conv3D_1_2024-03-0313_31_46.421778\model-00001-1.53340-0.42986-3.02183-0.18000.h5
# 67/67 [==============================] - 200s 3s/step - loss: 1.5334 - categorical_accuracy: 0.4299 - val_loss: 3.0218 - val_categorical_accuracy: 0.1800 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss: 1.0735 - categorical_accuracy: 0.6063
# Epoch 2: val_loss did not improve from 3.02183
# 67/67 [==============================] - 183s 3s/step - loss: 1.0735 - categorical_accuracy: 0.6063 - val_loss: 3.3467 - val_categorical_accuracy: 0.2400 - lr: 0.0010
# Epoch 3/20
# 67/67 [==============================] - ETA: 0s - loss: 0.9038 - categorical_accuracy: 0.6878
# Epoch 3: val_loss did not improve from 3.02183
# 67/67 [==============================] - 183s 3s/step - loss: 0.9038 - categorical_accuracy: 0.6878 - val_loss: 3.2298 - val_categorical_accuracy: 0.2400 - lr: 0.0010
# Epoch 4/20
# 67/67 [==============================] - ETA: 0s - loss: 0.7549 - categorical_accuracy: 0.7029
# Epoch 4: val_loss did not improve from 3.02183
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 184s 3s/step - loss: 0.7549 - categorical_accuracy: 0.7029 - val_loss: 4.4690 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 5/20
# 67/67 [==============================] - ETA: 0s - loss: 0.5636 - categorical_accuracy: 0.7843
# Epoch 5: val_loss improved from 3.02183 to 2.66120, saving model to model_conv3D_1_2024-03-0313_31_46.421778\model-00005-0.56362-0.78431-2.66120-0.23000.h5
# 67/67 [==============================] - 180s 3s/step - loss: 0.5636 - categorical_accuracy: 0.7843 - val_loss: 2.6612 - val_categorical_accuracy: 0.2300 - lr: 1.0000e-04
# Epoch 6/20
# 67/67 [==============================] - ETA: 0s - loss: 0.5204 - categorical_accuracy: 0.8160
# Epoch 6: val_loss improved from 2.66120 to 2.09557, saving model to model_conv3D_1_2024-03-0313_31_46.421778\model-00006-0.52039-0.81599-2.09557-0.41000.h5
# 67/67 [==============================] - 192s 3s/step - loss: 0.5204 - categorical_accuracy: 0.8160 - val_loss: 2.0956 - val_categorical_accuracy: 0.4100 - lr: 1.0000e-04
# Epoch 7/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4753 - categorical_accuracy: 0.8265
# Epoch 7: val_loss improved from 2.09557 to 1.32919, saving model to model_conv3D_1_2024-03-0313_31_46.421778\model-00007-0.47525-0.82655-1.32919-0.58000.h5
# 67/67 [==============================] - 182s 3s/step - loss: 0.4753 - categorical_accuracy: 0.8265 - val_loss: 1.3292 - val_categorical_accuracy: 0.5800 - lr: 1.0000e-04
# Epoch 8/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4298 - categorical_accuracy: 0.8446
# Epoch 8: val_loss improved from 1.32919 to 1.05838, saving model to model_conv3D_1_2024-03-0313_31_46.421778\model-00008-0.42983-0.84465-1.05838-0.66000.h5
# 67/67 [==============================] - 181s 3s/step - loss: 0.4298 - categorical_accuracy: 0.8446 - val_loss: 1.0584 - val_categorical_accuracy: 0.6600 - lr: 1.0000e-04
# Epoch 9/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4189 - categorical_accuracy: 0.8477
# Epoch 9: val_loss improved from 1.05838 to 0.65699, saving model to model_conv3D_1_2024-03-0313_31_46.421778\model-00009-0.41892-0.84766-0.65699-0.72000.h5
# 67/67 [==============================] - 177s 3s/step - loss: 0.4189 - categorical_accuracy: 0.8477 - val_loss: 0.6570 - val_categorical_accuracy: 0.7200 - lr: 1.0000e-04
# Epoch 10/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3666 - categorical_accuracy: 0.8703
# Epoch 10: val_loss did not improve from 0.65699
# 67/67 [==============================] - 178s 3s/step - loss: 0.3666 - categorical_accuracy: 0.8703 - val_loss: 0.8059 - val_categorical_accuracy: 0.7400 - lr: 1.0000e-04
# Epoch 11/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3530 - categorical_accuracy: 0.8612
# Epoch 11: val_loss did not improve from 0.65699
# 67/67 [==============================] - 183s 3s/step - loss: 0.3530 - categorical_accuracy: 0.8612 - val_loss: 0.7430 - val_categorical_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 12/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3023 - categorical_accuracy: 0.8884
# Epoch 12: val_loss did not improve from 0.65699
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 178s 3s/step - loss: 0.3023 - categorical_accuracy: 0.8884 - val_loss: 0.6836 - val_categorical_accuracy: 0.8500 - lr: 1.0000e-04
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3101 - categorical_accuracy: 0.8944
# Epoch 13: val_loss improved from 0.65699 to 0.58880, saving model to model_conv3D_1_2024-03-0313_31_46.421778\model-00013-0.31007-0.89442-0.58880-0.88000.h5
# 67/67 [==============================] - 177s 3s/step - loss: 0.3101 - categorical_accuracy: 0.8944 - val_loss: 0.5888 - val_categorical_accuracy: 0.8800 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2686 - categorical_accuracy: 0.9080
# Epoch 14: val_loss did not improve from 0.58880
# 67/67 [==============================] - 178s 3s/step - loss: 0.2686 - categorical_accuracy: 0.9080 - val_loss: 0.7678 - val_categorical_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2375 - categorical_accuracy: 0.9261
# Epoch 15: val_loss improved from 0.58880 to 0.47481, saving model to model_conv3D_1_2024-03-0313_31_46.421778\model-00015-0.23751-0.92609-0.47481-0.85000.h5
# 67/67 [==============================] - 178s 3s/step - loss: 0.2375 - categorical_accuracy: 0.9261 - val_loss: 0.4748 - val_categorical_accuracy: 0.8500 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2112 - categorical_accuracy: 0.9291
# Epoch 16: val_loss improved from 0.47481 to 0.32356, saving model to model_conv3D_1_2024-03-0313_31_46.421778\model-00016-0.21125-0.92911-0.32356-0.87000.h5
# 67/67 [==============================] - 194s 3s/step - loss: 0.2112 - categorical_accuracy: 0.9291 - val_loss: 0.3236 - val_categorical_accuracy: 0.8700 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2088 - categorical_accuracy: 0.9276
# Epoch 17: val_loss did not improve from 0.32356
# 67/67 [==============================] - 177s 3s/step - loss: 0.2088 - categorical_accuracy: 0.9276 - val_loss: 0.8461 - val_categorical_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1778 - categorical_accuracy: 0.9321
# Epoch 18: val_loss did not improve from 0.32356
# 67/67 [==============================] - 177s 3s/step - loss: 0.1778 - categorical_accuracy: 0.9321 - val_loss: 0.4652 - val_categorical_accuracy: 0.8800 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1653 - categorical_accuracy: 0.9532
# Epoch 19: val_loss improved from 0.32356 to 0.31175, saving model to model_conv3D_1_2024-03-0313_31_46.421778\model-00019-0.16532-0.95324-0.31175-0.88000.h5
# 67/67 [==============================] - 179s 3s/step - loss: 0.1653 - categorical_accuracy: 0.9532 - val_loss: 0.3117 - val_categorical_accuracy: 0.8800 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2169 - categorical_accuracy: 0.9216
# Epoch 20: val_loss did not improve from 0.31175
# 67/67 [==============================] - 190s 3s/step - loss: 0.2169 - categorical_accuracy: 0.9216 - val_loss: 0.6388 - val_categorical_accuracy: 0.8900 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 2: Conv 3D Model with 20 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 20 # choose the number of epochs
#print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # batch size = 10
# # num_frames per video = 20
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_8 (Conv3D)           (None, 20, 120, 120, 16)  1312
#
#  activation_14 (Activation)  (None, 20, 120, 120, 16)  0
#
#  batch_normalization_12 (Bat  (None, 20, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_8 (MaxPooling  (None, 10, 60, 60, 16)   0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 10, 60, 60, 32)    13856
#
#  activation_15 (Activation)  (None, 10, 60, 60, 32)    0
#
#  batch_normalization_13 (Bat  (None, 10, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_9 (MaxPooling  (None, 5, 30, 30, 32)    0
#  3D)
#
#  conv3d_10 (Conv3D)          (None, 5, 30, 30, 64)     55360
#
#  activation_16 (Activation)  (None, 5, 30, 30, 64)     0
#
#  batch_normalization_14 (Bat  (None, 5, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_10 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_11 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_17 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_15 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dense_6 (Dense)             (None, 256)               1605888
#
#  activation_18 (Activation)  (None, 256)               0
#
#  batch_normalization_16 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  activation_19 (Activation)  (None, 128)               0
#
#  batch_normalization_17 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 5)                 645
#
#  activation_20 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 1,933,765
# Trainable params: 1,932,517
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_2")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 [============================>.] - ETA: 3s - loss: 1.5333 - categorical_accuracy: 0.4538
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1.5296 - categorical_accuracy: 0.4570
# Epoch 1: val_loss improved from inf to 2.59461, saving model to model_conv3D_2_2024-03-0313_31_46.421778\model-00001-1.52959-0.45701-2.59461-0.19000.h5
# 67/67 [==============================] - 137s 2s/step - loss: 1.5296 - categorical_accuracy: 0.4570 - val_loss: 2.5946 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss: 1.0182 - categorical_accuracy: 0.6154
# Epoch 2: val_loss did not improve from 2.59461
# 67/67 [==============================] - 120s 2s/step - loss: 1.0182 - categorical_accuracy: 0.6154 - val_loss: 2.9778 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 3/20
# 67/67 [==============================] - ETA: 0s - loss: 0.7468 - categorical_accuracy: 0.7179
# Epoch 3: val_loss did not improve from 2.59461
# 67/67 [==============================] - 120s 2s/step - loss: 0.7468 - categorical_accuracy: 0.7179 - val_loss: 4.0308 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 4/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4631 - categorical_accuracy: 0.8145
# Epoch 4: val_loss did not improve from 2.59461
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 117s 2s/step - loss: 0.4631 - categorical_accuracy: 0.8145 - val_loss: 2.8748 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 5/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3375 - categorical_accuracy: 0.8733
# Epoch 5: val_loss did not improve from 2.59461
# 67/67 [==============================] - 119s 2s/step - loss: 0.3375 - categorical_accuracy: 0.8733 - val_loss: 2.8418 - val_categorical_accuracy: 0.1700 - lr: 1.0000e-04
# Epoch 6/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3017 - categorical_accuracy: 0.8944
# Epoch 6: val_loss improved from 2.59461 to 2.08034, saving model to model_conv3D_2_2024-03-0313_31_46.421778\model-00006-0.30167-0.89442-2.08034-0.34000.h5
# 67/67 [==============================] - 119s 2s/step - loss: 0.3017 - categorical_accuracy: 0.8944 - val_loss: 2.0803 - val_categorical_accuracy: 0.3400 - lr: 1.0000e-04
# Epoch 7/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2876 - categorical_accuracy: 0.8974
# Epoch 7: val_loss improved from 2.08034 to 0.89665, saving model to model_conv3D_2_2024-03-0313_31_46.421778\model-00007-0.28761-0.89744-0.89665-0.60000.h5
# 67/67 [==============================] - 118s 2s/step - loss: 0.2876 - categorical_accuracy: 0.8974 - val_loss: 0.8966 - val_categorical_accuracy: 0.6000 - lr: 1.0000e-04
# Epoch 8/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2208 - categorical_accuracy: 0.9201
# Epoch 8: val_loss improved from 0.89665 to 0.72438, saving model to model_conv3D_2_2024-03-0313_31_46.421778\model-00008-0.22084-0.92006-0.72438-0.71000.h5
# 67/67 [==============================] - 133s 2s/step - loss: 0.2208 - categorical_accuracy: 0.9201 - val_loss: 0.7244 - val_categorical_accuracy: 0.7100 - lr: 1.0000e-04
# Epoch 9/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2392 - categorical_accuracy: 0.9261
# Epoch 9: val_loss improved from 0.72438 to 0.51008, saving model to model_conv3D_2_2024-03-0313_31_46.421778\model-00009-0.23917-0.92609-0.51008-0.79000.h5
# 67/67 [==============================] - 136s 2s/step - loss: 0.2392 - categorical_accuracy: 0.9261 - val_loss: 0.5101 - val_categorical_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 10/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1849 - categorical_accuracy: 0.9397
# Epoch 10: val_loss improved from 0.51008 to 0.29828, saving model to model_conv3D_2_2024-03-0313_31_46.421778\model-00010-0.18495-0.93967-0.29828-0.91000.h5
# 67/67 [==============================] - 120s 2s/step - loss: 0.1849 - categorical_accuracy: 0.9397 - val_loss: 0.2983 - val_categorical_accuracy: 0.9100 - lr: 1.0000e-04
# Epoch 11/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1759 - categorical_accuracy: 0.9442
# Epoch 11: val_loss improved from 0.29828 to 0.28926, saving model to model_conv3D_2_2024-03-0313_31_46.421778\model-00011-0.17585-0.94419-0.28926-0.88000.h5
# 67/67 [==============================] - 118s 2s/step - loss: 0.1759 - categorical_accuracy: 0.9442 - val_loss: 0.2893 - val_categorical_accuracy: 0.8800 - lr: 1.0000e-04
# Epoch 12/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1764 - categorical_accuracy: 0.9427
# Epoch 12: val_loss improved from 0.28926 to 0.23685, saving model to model_conv3D_2_2024-03-0313_31_46.421778\model-00012-0.17636-0.94268-0.23685-0.92000.h5
# 67/67 [==============================] - 129s 2s/step - loss: 0.1764 - categorical_accuracy: 0.9427 - val_loss: 0.2368 - val_categorical_accuracy: 0.9200 - lr: 1.0000e-04
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1916 - categorical_accuracy: 0.9336
# Epoch 13: val_loss did not improve from 0.23685
# 67/67 [==============================] - 134s 2s/step - loss: 0.1916 - categorical_accuracy: 0.9336 - val_loss: 0.3147 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1239 - categorical_accuracy: 0.9683
# Epoch 14: val_loss did not improve from 0.23685
# 67/67 [==============================] - 120s 2s/step - loss: 0.1239 - categorical_accuracy: 0.9683 - val_loss: 0.2841 - val_categorical_accuracy: 0.8800 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1222 - categorical_accuracy: 0.9683
# Epoch 15: val_loss improved from 0.23685 to 0.18323, saving model to model_conv3D_2_2024-03-0313_31_46.421778\model-00015-0.12217-0.96833-0.18323-0.94000.h5
# 67/67 [==============================] - 118s 2s/step - loss: 0.1222 - categorical_accuracy: 0.9683 - val_loss: 0.1832 - val_categorical_accuracy: 0.9400 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1145 - categorical_accuracy: 0.9638
# Epoch 16: val_loss did not improve from 0.18323
# 67/67 [==============================] - 118s 2s/step - loss: 0.1145 - categorical_accuracy: 0.9638 - val_loss: 0.2017 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1163 - categorical_accuracy: 0.9593
# Epoch 17: val_loss did not improve from 0.18323
# 67/67 [==============================] - 128s 2s/step - loss: 0.1163 - categorical_accuracy: 0.9593 - val_loss: 0.2811 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0947 - categorical_accuracy: 0.9683
# Epoch 18: val_loss did not improve from 0.18323
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 135s 2s/step - loss: 0.0947 - categorical_accuracy: 0.9683 - val_loss: 0.2266 - val_categorical_accuracy: 0.9200 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1385 - categorical_accuracy: 0.9517
# Epoch 19: val_loss did not improve from 0.18323
# 67/67 [==============================] - 121s 2s/step - loss: 0.1385 - categorical_accuracy: 0.9517 - val_loss: 0.2398 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0898 - categorical_accuracy: 0.9759
# Epoch 20: val_loss did not improve from 0.18323
# 67/67 [==============================] - 118s 2s/step - loss: 0.0898 - categorical_accuracy: 0.9759 - val_loss: 0.2325 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %% [markdown]
# #### Model 3: Conv 3D Model with 20 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 160 by 160)

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 160
width = 160

model = conv3D(num_images=num_frames, height=160, width=160)

print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num_frames per video = 20
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 20, 160, 160, 16)  1312
#
#  activation_21 (Activation)  (None, 20, 160, 160, 16)  0
#
#  batch_normalization_18 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_12 (MaxPoolin  (None, 10, 80, 80, 16)   0
#  g3D)
#
#  conv3d_13 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_22 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_19 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_13 (MaxPoolin  (None, 5, 40, 40, 32)    0
#  g3D)
#
#  conv3d_14 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_23 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_20 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_14 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
#  conv3d_15 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_24 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_21 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_15 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_3 (Flatten)         (None, 12800)             0
#
#  dense_9 (Dense)             (None, 256)               3277056
#
#  activation_25 (Activation)  (None, 256)               0
#
#  batch_normalization_22 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  activation_26 (Activation)  (None, 128)               0
#
#  batch_normalization_23 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 5)                 645
#
#  activation_27 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 3,604,933
# Trainable params: 3,603,685
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_3")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames, height=160, width=160)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames, height=160, width=160)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 [============================>.] - ETA: 3s - loss: 1.4499 - categorical_accuracy: 0.4831
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1.4524 - categorical_accuracy: 0.4811
# Epoch 1: val_loss improved from inf to 4.90941, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00001-1.45241-0.48115-4.90941-0.25000.h5
# 67/67 [==============================] - 154s 2s/step - loss: 1.4524 - categorical_accuracy: 0.4811 - val_loss: 4.9094 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss: 0.9154 - categorical_accuracy: 0.6772
# Epoch 2: val_loss improved from 4.90941 to 4.51945, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00002-0.91537-0.67722-4.51945-0.26000.h5
# 67/67 [==============================] - 152s 2s/step - loss: 0.9154 - categorical_accuracy: 0.6772 - val_loss: 4.5194 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 3/20
# 67/67 [==============================] - ETA: 0s - loss: 0.7090 - categorical_accuracy: 0.7466
# Epoch 3: val_loss improved from 4.51945 to 4.17015, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00003-0.70898-0.74661-4.17015-0.24000.h5
# 67/67 [==============================] - 151s 2s/step - loss: 0.7090 - categorical_accuracy: 0.7466 - val_loss: 4.1702 - val_categorical_accuracy: 0.2400 - lr: 0.0010
# Epoch 4/20
# 67/67 [==============================] - ETA: 0s - loss: 0.6133 - categorical_accuracy: 0.7587
# Epoch 4: val_loss did not improve from 4.17015
# 67/67 [==============================] - 149s 2s/step - loss: 0.6133 - categorical_accuracy: 0.7587 - val_loss: 4.2514 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 5/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4399 - categorical_accuracy: 0.8401
# Epoch 5: val_loss did not improve from 4.17015
# 67/67 [==============================] - 150s 2s/step - loss: 0.4399 - categorical_accuracy: 0.8401 - val_loss: 5.1825 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 6/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3866 - categorical_accuracy: 0.8552
# Epoch 6: val_loss did not improve from 4.17015
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 152s 2s/step - loss: 0.3866 - categorical_accuracy: 0.8552 - val_loss: 4.5779 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 7/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2915 - categorical_accuracy: 0.8854
# Epoch 7: val_loss improved from 4.17015 to 2.30675, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00007-0.29154-0.88537-2.30675-0.35000.h5
# 67/67 [==============================] - 152s 2s/step - loss: 0.2915 - categorical_accuracy: 0.8854 - val_loss: 2.3067 - val_categorical_accuracy: 0.3500 - lr: 1.0000e-04
# Epoch 8/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1962 - categorical_accuracy: 0.9382
# Epoch 8: val_loss improved from 2.30675 to 1.06875, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00008-0.19620-0.93816-1.06875-0.64000.h5
# 67/67 [==============================] - 155s 2s/step - loss: 0.1962 - categorical_accuracy: 0.9382 - val_loss: 1.0688 - val_categorical_accuracy: 0.6400 - lr: 1.0000e-04
# Epoch 9/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1692 - categorical_accuracy: 0.9442
# Epoch 9: val_loss improved from 1.06875 to 0.44093, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00009-0.16916-0.94419-0.44093-0.84000.h5
# 67/67 [==============================] - 150s 2s/step - loss: 0.1692 - categorical_accuracy: 0.9442 - val_loss: 0.4409 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04
# Epoch 10/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1666 - categorical_accuracy: 0.9427
# Epoch 10: val_loss improved from 0.44093 to 0.41147, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00010-0.16658-0.94268-0.41147-0.85000.h5
# 67/67 [==============================] - 151s 2s/step - loss: 0.1666 - categorical_accuracy: 0.9427 - val_loss: 0.4115 - val_categorical_accuracy: 0.8500 - lr: 1.0000e-04
# Epoch 11/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1891 - categorical_accuracy: 0.9397
# Epoch 11: val_loss improved from 0.41147 to 0.34446, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00011-0.18912-0.93967-0.34446-0.89000.h5
# 67/67 [==============================] - 151s 2s/step - loss: 0.1891 - categorical_accuracy: 0.9397 - val_loss: 0.3445 - val_categorical_accuracy: 0.8900 - lr: 1.0000e-04
# Epoch 12/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1849 - categorical_accuracy: 0.9336
# Epoch 12: val_loss improved from 0.34446 to 0.26669, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00012-0.18490-0.93363-0.26669-0.89000.h5
# 67/67 [==============================] - 151s 2s/step - loss: 0.1849 - categorical_accuracy: 0.9336 - val_loss: 0.2667 - val_categorical_accuracy: 0.8900 - lr: 1.0000e-04
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1354 - categorical_accuracy: 0.9593
# Epoch 13: val_loss improved from 0.26669 to 0.21756, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00013-0.13540-0.95928-0.21756-0.88000.h5
# 67/67 [==============================] - 153s 2s/step - loss: 0.1354 - categorical_accuracy: 0.9593 - val_loss: 0.2176 - val_categorical_accuracy: 0.8800 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1384 - categorical_accuracy: 0.9593
# Epoch 14: val_loss improved from 0.21756 to 0.20819, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00014-0.13839-0.95928-0.20819-0.93000.h5
# 67/67 [==============================] - 152s 2s/step - loss: 0.1384 - categorical_accuracy: 0.9593 - val_loss: 0.2082 - val_categorical_accuracy: 0.9300 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1922 - categorical_accuracy: 0.9397
# Epoch 15: val_loss improved from 0.20819 to 0.17280, saving model to model_conv3D_3_2024-03-0313_31_46.421778\model-00015-0.19217-0.93967-0.17280-0.94000.h5
# 67/67 [==============================] - 151s 2s/step - loss: 0.1922 - categorical_accuracy: 0.9397 - val_loss: 0.1728 - val_categorical_accuracy: 0.9400 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1547 - categorical_accuracy: 0.9472
# Epoch 16: val_loss did not improve from 0.17280
# 67/67 [==============================] - 150s 2s/step - loss: 0.1547 - categorical_accuracy: 0.9472 - val_loss: 0.3333 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0977 - categorical_accuracy: 0.9789
# Epoch 17: val_loss did not improve from 0.17280
# 67/67 [==============================] - 150s 2s/step - loss: 0.0977 - categorical_accuracy: 0.9789 - val_loss: 0.2356 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0872 - categorical_accuracy: 0.9713
# Epoch 18: val_loss did not improve from 0.17280
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 150s 2s/step - loss: 0.0872 - categorical_accuracy: 0.9713 - val_loss: 0.2682 - val_categorical_accuracy: 0.9200 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1130 - categorical_accuracy: 0.9668
# Epoch 19: val_loss did not improve from 0.17280
# 67/67 [==============================] - 150s 2s/step - loss: 0.1130 - categorical_accuracy: 0.9668 - val_loss: 0.2066 - val_categorical_accuracy: 0.9400 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1293 - categorical_accuracy: 0.9638
# Epoch 20: val_loss did not improve from 0.17280
# 67/67 [==============================] - 164s 2s/step - loss: 0.1293 - categorical_accuracy: 0.9638 - val_loss: 0.1863 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Conv 3D Model with 30 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer) + Random data transformations on training data set

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 15
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_16 (Conv3D)          (None, 30, 120, 120, 16)  1312
#
#  activation_28 (Activation)  (None, 30, 120, 120, 16)  0
#
#  batch_normalization_24 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_16 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_17 (Conv3D)          (None, 15, 60, 60, 32)    13856
#
#  activation_29 (Activation)  (None, 15, 60, 60, 32)    0
#
#  batch_normalization_25 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_17 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  conv3d_18 (Conv3D)          (None, 7, 30, 30, 64)     55360
#
#  activation_30 (Activation)  (None, 7, 30, 30, 64)     0
#
#  batch_normalization_26 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_18 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_19 (Conv3D)          (None, 3, 15, 15, 128)    221312
#
#  activation_31 (Activation)  (None, 3, 15, 15, 128)    0
#
#  batch_normalization_27 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_19 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_4 (Flatten)         (None, 6272)              0
#
#  dense_12 (Dense)            (None, 256)               1605888
#
#  activation_32 (Activation)  (None, 256)               0
#
#  batch_normalization_28 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  activation_33 (Activation)  (None, 128)               0
#
#  batch_normalization_29 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 5)                 645
#
#  activation_34 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 1,933,765
# Trainable params: 1,932,517
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_conv3D_4")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=True, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/15
# 65/67 [============================>.] - ETA: 5s - loss: 1.6765 - categorical_accuracy: 0.4185
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1.6732 - categorical_accuracy: 0.4178
# Epoch 1: val_loss improved from inf to 3.68637, saving model to model_conv3D_4_2024-03-0313_31_46.421778\model-00001-1.67323-0.41780-3.68637-0.21000.h5
# 67/67 [==============================] - 202s 3s/step - loss: 1.6732 - categorical_accuracy: 0.4178 - val_loss: 3.6864 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/15
# 67/67 [==============================] - ETA: 0s - loss: 1.2226 - categorical_accuracy: 0.5339
# Epoch 2: val_loss did not improve from 3.68637
# 67/67 [==============================] - 208s 3s/step - loss: 1.2226 - categorical_accuracy: 0.5339 - val_loss: 10.6357 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 3/15
# 67/67 [==============================] - ETA: 0s - loss: 1.2563 - categorical_accuracy: 0.5279
# Epoch 3: val_loss did not improve from 3.68637
# 67/67 [==============================] - 204s 3s/step - loss: 1.2563 - categorical_accuracy: 0.5279 - val_loss: 5.4549 - val_categorical_accuracy: 0.1400 - lr: 0.0010
# Epoch 4/15
# 67/67 [==============================] - ETA: 0s - loss: 1.0536 - categorical_accuracy: 0.6184
# Epoch 4: val_loss did not improve from 3.68637
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 210s 3s/step - loss: 1.0536 - categorical_accuracy: 0.6184 - val_loss: 5.1387 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 5/15
# 67/67 [==============================] - ETA: 0s - loss: 0.8354 - categorical_accuracy: 0.6742
# Epoch 5: val_loss did not improve from 3.68637
# 67/67 [==============================] - 232s 4s/step - loss: 0.8354 - categorical_accuracy: 0.6742 - val_loss: 4.3344 - val_categorical_accuracy: 0.3000 - lr: 1.0000e-04
# Epoch 6/15
# 67/67 [==============================] - ETA: 0s - loss: 0.7614 - categorical_accuracy: 0.7104
# Epoch 6: val_loss improved from 3.68637 to 3.02263, saving model to model_conv3D_4_2024-03-0313_31_46.421778\model-00006-0.76137-0.71041-3.02263-0.27000.h5
# 67/67 [==============================] - 231s 3s/step - loss: 0.7614 - categorical_accuracy: 0.7104 - val_loss: 3.0226 - val_categorical_accuracy: 0.2700 - lr: 1.0000e-04
# Epoch 7/15
# 67/67 [==============================] - ETA: 0s - loss: 0.7259 - categorical_accuracy: 0.7240
# Epoch 7: val_loss improved from 3.02263 to 2.61996, saving model to model_conv3D_4_2024-03-0313_31_46.421778\model-00007-0.72593-0.72398-2.61996-0.30000.h5
# 67/67 [==============================] - 218s 3s/step - loss: 0.7259 - categorical_accuracy: 0.7240 - val_loss: 2.6200 - val_categorical_accuracy: 0.3000 - lr: 1.0000e-04
# Epoch 8/15
# 67/67 [==============================] - ETA: 0s - loss: 0.6551 - categorical_accuracy: 0.7526
# Epoch 8: val_loss improved from 2.61996 to 1.98286, saving model to model_conv3D_4_2024-03-0313_31_46.421778\model-00008-0.65507-0.75264-1.98286-0.44000.h5
# 67/67 [==============================] - 202s 3s/step - loss: 0.6551 - categorical_accuracy: 0.7526 - val_loss: 1.9829 - val_categorical_accuracy: 0.4400 - lr: 1.0000e-04
# Epoch 9/15
# 67/67 [==============================] - ETA: 0s - loss: 0.6177 - categorical_accuracy: 0.7511
# Epoch 9: val_loss did not improve from 1.98286
# 67/67 [==============================] - 223s 3s/step - loss: 0.6177 - categorical_accuracy: 0.7511 - val_loss: 2.1253 - val_categorical_accuracy: 0.3700 - lr: 1.0000e-04
# Epoch 10/15
# 67/67 [==============================] - ETA: 0s - loss: 0.6064 - categorical_accuracy: 0.7647
# Epoch 10: val_loss improved from 1.98286 to 1.84728, saving model to model_conv3D_4_2024-03-0313_31_46.421778\model-00010-0.60636-0.76471-1.84728-0.44000.h5
# 67/67 [==============================] - 231s 3s/step - loss: 0.6064 - categorical_accuracy: 0.7647 - val_loss: 1.8473 - val_categorical_accuracy: 0.4400 - lr: 1.0000e-04
# Epoch 11/15
# 67/67 [==============================] - ETA: 0s - loss: 0.5301 - categorical_accuracy: 0.8024
# Epoch 11: val_loss improved from 1.84728 to 1.25947, saving model to model_conv3D_4_2024-03-0313_31_46.421778\model-00011-0.53008-0.80241-1.25947-0.54000.h5
# 67/67 [==============================] - 203s 3s/step - loss: 0.5301 - categorical_accuracy: 0.8024 - val_loss: 1.2595 - val_categorical_accuracy: 0.5400 - lr: 1.0000e-04
# Epoch 12/15
# 67/67 [==============================] - ETA: 0s - loss: 0.5528 - categorical_accuracy: 0.7798
# Epoch 12: val_loss improved from 1.25947 to 0.92037, saving model to model_conv3D_4_2024-03-0313_31_46.421778\model-00012-0.55279-0.77979-0.92037-0.61000.h5
# 67/67 [==============================] - 202s 3s/step - loss: 0.5528 - categorical_accuracy: 0.7798 - val_loss: 0.9204 - val_categorical_accuracy: 0.6100 - lr: 1.0000e-04
# Epoch 13/15
# 67/67 [==============================] - ETA: 0s - loss: 0.5109 - categorical_accuracy: 0.8084
# Epoch 13: val_loss did not improve from 0.92037
# 67/67 [==============================] - 201s 3s/step - loss: 0.5109 - categorical_accuracy: 0.8084 - val_loss: 1.0654 - val_categorical_accuracy: 0.6400 - lr: 1.0000e-04
# Epoch 14/15
# 67/67 [==============================] - ETA: 0s - loss: 0.4799 - categorical_accuracy: 0.8296
# Epoch 14: val_loss improved from 0.92037 to 0.80692, saving model to model_conv3D_4_2024-03-0313_31_46.421778\model-00014-0.47993-0.82956-0.80692-0.68000.h5
# 67/67 [==============================] - 202s 3s/step - loss: 0.4799 - categorical_accuracy: 0.8296 - val_loss: 0.8069 - val_categorical_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 15/15
# 67/67 [==============================] - ETA: 0s - loss: 0.4935 - categorical_accuracy: 0.8115
# Epoch 15: val_loss did not improve from 0.80692
# 67/67 [==============================] - 205s 3s/step - loss: 0.4935 - categorical_accuracy: 0.8115 - val_loss: 1.1151 - val_categorical_accuracy: 0.6500 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 5: Conv 3D Model with 30 frames per video (8, 16, 32, 64 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

conv_filters = (8, 16, 32, 64) 
model = conv3D(conv_filters, num_images=num_frames)
print (model.summary())
# Out:
# # epochs = 25
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_20 (Conv3D)          (None, 30, 120, 120, 8)   656
#
#  activation_35 (Activation)  (None, 30, 120, 120, 8)   0
#
#  batch_normalization_30 (Bat  (None, 30, 120, 120, 8)  32
#  chNormalization)
#
#  max_pooling3d_20 (MaxPoolin  (None, 15, 60, 60, 8)    0
#  g3D)
#
#  conv3d_21 (Conv3D)          (None, 15, 60, 60, 16)    3472
#
#  activation_36 (Activation)  (None, 15, 60, 60, 16)    0
#
#  batch_normalization_31 (Bat  (None, 15, 60, 60, 16)   64
#  chNormalization)
#
#  max_pooling3d_21 (MaxPoolin  (None, 7, 30, 30, 16)    0
#  g3D)
#
#  conv3d_22 (Conv3D)          (None, 7, 30, 30, 32)     13856
#
#  activation_37 (Activation)  (None, 7, 30, 30, 32)     0
#
#  batch_normalization_32 (Bat  (None, 7, 30, 30, 32)    128
#  chNormalization)
#
#  max_pooling3d_22 (MaxPoolin  (None, 3, 15, 15, 32)    0
#  g3D)
#
#  conv3d_23 (Conv3D)          (None, 3, 15, 15, 64)     55360
#
#  activation_38 (Activation)  (None, 3, 15, 15, 64)     0
#
#  batch_normalization_33 (Bat  (None, 3, 15, 15, 64)    256
#  chNormalization)
#
#  max_pooling3d_23 (MaxPoolin  (None, 1, 7, 7, 64)      0
#  g3D)
#
#  flatten_5 (Flatten)         (None, 3136)              0
#
#  dense_15 (Dense)            (None, 256)               803072
#
#  activation_39 (Activation)  (None, 256)               0
#
#  batch_normalization_34 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  activation_40 (Activation)  (None, 128)               0
#
#  batch_normalization_35 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 5)                 645
#
#  activation_41 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 911,973
# Trainable params: 910,965
# Non-trainable params: 1,008
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_conv3D_5")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/25
# 65/67 [============================>.] - ETA: 4s - loss: 1.5168 - categorical_accuracy: 0.4754
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:74: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 [==============================] - ETA: 0s - loss: 1.5141 - categorical_accuracy: 0.4781
# Epoch 1: val_loss improved from inf to 6.86471, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00001-1.51405-0.47813-6.86471-0.16000.h5
# 67/67 [==============================] - 182s 3s/step - loss: 1.5141 - categorical_accuracy: 0.4781 - val_loss: 6.8647 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/25
# 67/67 [==============================] - ETA: 0s - loss: 1.0125 - categorical_accuracy: 0.6320
# Epoch 2: val_loss did not improve from 6.86471
# 67/67 [==============================] - 180s 3s/step - loss: 1.0125 - categorical_accuracy: 0.6320 - val_loss: 10.4701 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 3/25
# 67/67 [==============================] - ETA: 0s - loss: 0.7844 - categorical_accuracy: 0.6878
# Epoch 3: val_loss improved from 6.86471 to 4.14521, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00003-0.78437-0.68778-4.14521-0.16000.h5
# 67/67 [==============================] - 178s 3s/step - loss: 0.7844 - categorical_accuracy: 0.6878 - val_loss: 4.1452 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 4/25
# 67/67 [==============================] - ETA: 0s - loss: 0.5093 - categorical_accuracy: 0.7903
# Epoch 4: val_loss improved from 4.14521 to 3.43140, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00004-0.50934-0.79035-3.43140-0.22000.h5
# 67/67 [==============================] - 179s 3s/step - loss: 0.5093 - categorical_accuracy: 0.7903 - val_loss: 3.4314 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 5/25
# 67/67 [==============================] - ETA: 0s - loss: 0.4931 - categorical_accuracy: 0.8205
# Epoch 5: val_loss improved from 3.43140 to 2.83609, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00005-0.49307-0.82051-2.83609-0.38000.h5
# 67/67 [==============================] - 178s 3s/step - loss: 0.4931 - categorical_accuracy: 0.8205 - val_loss: 2.8361 - val_categorical_accuracy: 0.3800 - lr: 0.0010
# Epoch 6/25
# 67/67 [==============================] - ETA: 0s - loss: 0.6566 - categorical_accuracy: 0.7662
# Epoch 6: val_loss improved from 2.83609 to 1.52902, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00006-0.65660-0.76621-1.52902-0.58000.h5
# 67/67 [==============================] - 177s 3s/step - loss: 0.6566 - categorical_accuracy: 0.7662 - val_loss: 1.5290 - val_categorical_accuracy: 0.5800 - lr: 0.0010
# Epoch 7/25
# 67/67 [==============================] - ETA: 0s - loss: 0.5976 - categorical_accuracy: 0.7888
# Epoch 7: val_loss improved from 1.52902 to 1.36036, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00007-0.59756-0.78884-1.36036-0.63000.h5
# 67/67 [==============================] - 179s 3s/step - loss: 0.5976 - categorical_accuracy: 0.7888 - val_loss: 1.3604 - val_categorical_accuracy: 0.6300 - lr: 0.0010
# Epoch 8/25
# 67/67 [==============================] - ETA: 0s - loss: 0.3989 - categorical_accuracy: 0.8688
# Epoch 8: val_loss did not improve from 1.36036
# 67/67 [==============================] - 179s 3s/step - loss: 0.3989 - categorical_accuracy: 0.8688 - val_loss: 1.3663 - val_categorical_accuracy: 0.5500 - lr: 0.0010
# Epoch 9/25
# 67/67 [==============================] - ETA: 0s - loss: 0.3211 - categorical_accuracy: 0.8824
# Epoch 9: val_loss improved from 1.36036 to 0.95300, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00009-0.32109-0.88235-0.95300-0.66000.h5
# 67/67 [==============================] - 191s 3s/step - loss: 0.3211 - categorical_accuracy: 0.8824 - val_loss: 0.9530 - val_categorical_accuracy: 0.6600 - lr: 0.0010
# Epoch 10/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2693 - categorical_accuracy: 0.8944
# Epoch 10: val_loss did not improve from 0.95300
# 67/67 [==============================] - 187s 3s/step - loss: 0.2693 - categorical_accuracy: 0.8944 - val_loss: 0.9540 - val_categorical_accuracy: 0.6400 - lr: 0.0010
# Epoch 11/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2724 - categorical_accuracy: 0.9035
# Epoch 11: val_loss improved from 0.95300 to 0.54577, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00011-0.27242-0.90347-0.54577-0.85000.h5
# 67/67 [==============================] - 183s 3s/step - loss: 0.2724 - categorical_accuracy: 0.9035 - val_loss: 0.5458 - val_categorical_accuracy: 0.8500 - lr: 0.0010
# Epoch 12/25
# 67/67 [==============================] - ETA: 0s - loss: 0.3220 - categorical_accuracy: 0.8778
# Epoch 12: val_loss did not improve from 0.54577
# 67/67 [==============================] - 178s 3s/step - loss: 0.3220 - categorical_accuracy: 0.8778 - val_loss: 1.6572 - val_categorical_accuracy: 0.6300 - lr: 0.0010
# Epoch 13/25
# 67/67 [==============================] - ETA: 0s - loss: 0.3134 - categorical_accuracy: 0.8854
# Epoch 13: val_loss did not improve from 0.54577
# 67/67 [==============================] - 179s 3s/step - loss: 0.3134 - categorical_accuracy: 0.8854 - val_loss: 0.6221 - val_categorical_accuracy: 0.7900 - lr: 0.0010
# Epoch 14/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2128 - categorical_accuracy: 0.9382
# Epoch 14: val_loss improved from 0.54577 to 0.49495, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00014-0.21275-0.93816-0.49495-0.82000.h5
# 67/67 [==============================] - 179s 3s/step - loss: 0.2128 - categorical_accuracy: 0.9382 - val_loss: 0.4950 - val_categorical_accuracy: 0.8200 - lr: 0.0010
# Epoch 15/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1641 - categorical_accuracy: 0.9412
# Epoch 15: val_loss did not improve from 0.49495
# 67/67 [==============================] - 179s 3s/step - loss: 0.1641 - categorical_accuracy: 0.9412 - val_loss: 0.5117 - val_categorical_accuracy: 0.8300 - lr: 0.0010
# Epoch 16/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1398 - categorical_accuracy: 0.9502
# Epoch 16: val_loss improved from 0.49495 to 0.32286, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00016-0.13985-0.95023-0.32286-0.92000.h5
# 67/67 [==============================] - 179s 3s/step - loss: 0.1398 - categorical_accuracy: 0.9502 - val_loss: 0.3229 - val_categorical_accuracy: 0.9200 - lr: 0.0010
# Epoch 17/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1389 - categorical_accuracy: 0.9532
# Epoch 17: val_loss did not improve from 0.32286
# 67/67 [==============================] - 178s 3s/step - loss: 0.1389 - categorical_accuracy: 0.9532 - val_loss: 0.5223 - val_categorical_accuracy: 0.7800 - lr: 0.0010
# Epoch 18/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1603 - categorical_accuracy: 0.9442
# Epoch 18: val_loss did not improve from 0.32286
# 67/67 [==============================] - 178s 3s/step - loss: 0.1603 - categorical_accuracy: 0.9442 - val_loss: 0.6750 - val_categorical_accuracy: 0.7700 - lr: 0.0010
# Epoch 19/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1657 - categorical_accuracy: 0.9397
# Epoch 19: val_loss did not improve from 0.32286
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 177s 3s/step - loss: 0.1657 - categorical_accuracy: 0.9397 - val_loss: 0.3291 - val_categorical_accuracy: 0.8700 - lr: 0.0010
# Epoch 20/25
# 67/67 [==============================] - ETA: 0s - loss: 0.0806 - categorical_accuracy: 0.9789
# Epoch 20: val_loss improved from 0.32286 to 0.31416, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00020-0.08064-0.97888-0.31416-0.89000.h5
# 67/67 [==============================] - 179s 3s/step - loss: 0.0806 - categorical_accuracy: 0.9789 - val_loss: 0.3142 - val_categorical_accuracy: 0.8900 - lr: 1.0000e-04
# Epoch 21/25
# 67/67 [==============================] - ETA: 0s - loss: 0.0552 - categorical_accuracy: 0.9834
# Epoch 21: val_loss did not improve from 0.31416
# 67/67 [==============================] - 178s 3s/step - loss: 0.0552 - categorical_accuracy: 0.9834 - val_loss: 0.3192 - val_categorical_accuracy: 0.9200 - lr: 1.0000e-04
# Epoch 22/25
# 67/67 [==============================] - ETA: 0s - loss: 0.0623 - categorical_accuracy: 0.9864
# Epoch 22: val_loss did not improve from 0.31416
# 67/67 [==============================] - 179s 3s/step - loss: 0.0623 - categorical_accuracy: 0.9864 - val_loss: 0.3423 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 23/25
# 67/67 [==============================] - ETA: 0s - loss: 0.0710 - categorical_accuracy: 0.9744
# Epoch 23: val_loss improved from 0.31416 to 0.30122, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00023-0.07103-0.97436-0.30122-0.92000.h5
# 67/67 [==============================] - 179s 3s/step - loss: 0.0710 - categorical_accuracy: 0.9744 - val_loss: 0.3012 - val_categorical_accuracy: 0.9200 - lr: 1.0000e-04
# Epoch 24/25
# 67/67 [==============================] - ETA: 0s - loss: 0.0539 - categorical_accuracy: 0.9864
# Epoch 24: val_loss improved from 0.30122 to 0.30040, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00024-0.05389-0.98643-0.30040-0.91000.h5
# 67/67 [==============================] - 178s 3s/step - loss: 0.0539 - categorical_accuracy: 0.9864 - val_loss: 0.3004 - val_categorical_accuracy: 0.9100 - lr: 1.0000e-04
# Epoch 25/25
# 67/67 [==============================] - ETA: 0s - loss: 0.0759 - categorical_accuracy: 0.9729
# Epoch 25: val_loss improved from 0.30040 to 0.21909, saving model to model_conv3D_5_2024-03-0313_31_46.421778\model-00025-0.07594-0.97285-0.21909-0.95000.h5
# 67/67 [==============================] - 179s 3s/step - loss: 0.0759 - categorical_accuracy: 0.9729 - val_loss: 0.2191 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 6: Conv 3D Model with 20 frames per video (32, 64, 128, 256) filters conv 3D layers + 128 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 20  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 120
width = 120

conv_filters = (32, 64, 128, 256)
dense_filters = (128, 128)
model = conv3D(conv_filters=conv_filters,dense_nodes=dense_filters, num_images=num_frames)
print (model.summary())
# Out:
# # epochs = 25
# # batch size = 20
# # num_frames per video = 20
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_36 (Conv3D)          (None, 20, 120, 120, 32)  2624
#
#  activation_57 (Activation)  (None, 20, 120, 120, 32)  0
#
#  batch_normalization_50 (Bat  (None, 20, 120, 120, 32)  128
#  chNormalization)
#
#  max_pooling3d_36 (MaxPoolin  (None, 10, 60, 60, 32)   0
#  g3D)
#
#  conv3d_37 (Conv3D)          (None, 10, 60, 60, 64)    55360
#
#  activation_58 (Activation)  (None, 10, 60, 60, 64)    0
#
#  batch_normalization_51 (Bat  (None, 10, 60, 60, 64)   256
#  chNormalization)
#
#  max_pooling3d_37 (MaxPoolin  (None, 5, 30, 30, 64)    0
#  g3D)
#
#  conv3d_38 (Conv3D)          (None, 5, 30, 30, 128)    221312
#
#  activation_59 (Activation)  (None, 5, 30, 30, 128)    0
#
#  batch_normalization_52 (Bat  (None, 5, 30, 30, 128)   512
#  chNormalization)
#
#  max_pooling3d_38 (MaxPoolin  (None, 2, 15, 15, 128)   0
#  g3D)
#
#  conv3d_39 (Conv3D)          (None, 2, 15, 15, 256)    884992
#
#  activation_60 (Activation)  (None, 2, 15, 15, 256)    0
#
#  batch_normalization_53 (Bat  (None, 2, 15, 15, 256)   1024
#  chNormalization)
#
#  max_pooling3d_39 (MaxPoolin  (None, 1, 7, 7, 256)     0
#  g3D)
#
#  flatten_7 (Flatten)         (None, 12544)             0
#
#  dense_21 (Dense)            (None, 128)               1605760
#
#  activation_61 (Activation)  (None, 128)               0
#
#  batch_normalization_54 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_22 (Dense)            (None, 128)               16512
#
#  activation_62 (Activation)  (None, 128)               0
#
#  batch_normalization_55 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_23 (Dense)            (None, 5)                 645
#
#  activation_63 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 2,790,149
# Trainable params: 2,788,677
# Non-trainable params: 1,472
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_conv3D_6")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=False, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\109625498.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/25
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
#       2                               callbacks=callbacks_list, validation_data=val_generator,
#       3                               validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
#
# File c:\anaconda3\envs\py310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'gradient_tape/sequential_9/max_pooling3d_37/MaxPool3D/MaxPool3DGrad' defined at (most recent call last):
#     File "c:\anaconda3\envs\py310\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\anaconda3\envs\py310\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "c:\anaconda3\envs\py310\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\anaconda3\envs\py310\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\anaconda3\envs\py310\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\anaconda3\envs\py310\lib\asyncio\base_events.py", line 603, in run_forever
#       self._run_once()
#     File "c:\anaconda3\envs\py310\lib\asyncio\base_events.py", line 1909, in _run_once
#       handle._run()
#     File "c:\anaconda3\envs\py310\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\anaconda3\envs\py310\lib\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\anaconda3\envs\py310\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\anaconda3\envs\py310\lib\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#       res = shell.run_cell(
#     File "c:\anaconda3\envs\py310\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#       result = self._run_cell(
#     File "c:\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#       result = runner(coro)
#     File "c:\anaconda3\envs\py310\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\PRATIK SINHA\AppData\Local\Temp\ipykernel_13976\2699507389.py", line 1, in <module>
#       history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
#     File "c:\anaconda3\envs\py310\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\anaconda3\envs\py310\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "c:\anaconda3\envs\py310\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "c:\anaconda3\envs\py310\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\anaconda3\envs\py310\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "c:\anaconda3\envs\py310\lib\site-packages\keras\engine\training.py", line 997, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "c:\anaconda3\envs\py310\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 576, in minimize
#       grads_and_vars = self._compute_gradients(
#     File "c:\anaconda3\envs\py310\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 634, in _compute_gradients
#       grads_and_vars = self._get_gradients(
#     File "c:\anaconda3\envs\py310\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 510, in _get_gradients
#       grads = tape.gradient(loss, var_list, grad_loss)
# Node: 'gradient_tape/sequential_9/max_pooling3d_37/MaxPool3D/MaxPool3DGrad'
# OOM when allocating tensor with shape[20,64,5,30,30] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradient_tape/sequential_9/max_pooling3d_37/MaxPool3D/MaxPool3DGrad}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_60640]

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 7: Conv 3D Model with 30 frames per video and a 5 by 5 filter size (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
#write your model here
def conv3D_5by5(conv_filters=(16, 32, 64, 128), dense_nodes=(256,128), dropout=0.25, num_images=20, height=120, width=120):

    model = Sequential()

    model.add(Conv3D(conv_filters[0], (5, 5, 5), padding='same', input_shape=(num_images, height, width, 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(conv_filters[1], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[2], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[3], (3, 3, 3), padding='same'))    
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Flatten())
    model.add(Dense(dense_nodes[0]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(dense_nodes[1]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    opt = tf.keras.optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    
    return model

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 5  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D_5by5(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 15
#
# # batch size = 5
#
# # num_frames per video = 30
#
# Model: "sequential_5"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  conv3d_20 (Conv3D)          (None, 30, 120, 120, 16)  6016
#
#
#
#  activation_35 (Activation)  (None, 30, 120, 120, 16)  0
#
#
#
#  batch_normalization_30 (Bat  (None, 30, 120, 120, 16)  64
#
#  chNormalization)
#
#
#
#  max_pooling3d_20 (MaxPoolin  (None, 15, 60, 60, 16)   0
#
#  g3D)
#
#
#
#  conv3d_21 (Conv3D)          (None, 15, 60, 60, 32)    13856
#
#
#
#  activation_36 (Activation)  (None, 15, 60, 60, 32)    0
#
#
#
#  batch_normalization_31 (Bat  (None, 15, 60, 60, 32)   128
#
#  chNormalization)
#
#
#
#  max_pooling3d_21 (MaxPoolin  (None, 7, 30, 30, 32)    0
#
#  g3D)
#
#
#
#  conv3d_22 (Conv3D)          (None, 7, 30, 30, 64)     55360
#
#
#
#  activation_37 (Activation)  (None, 7, 30, 30, 64)     0
#
#
#
#  batch_normalization_32 (Bat  (None, 7, 30, 30, 64)    256
#
#  chNormalization)
#
#
#
#  max_pooling3d_22 (MaxPoolin  (None, 3, 15, 15, 64)    0
#
#  g3D)
#
#
#
#  conv3d_23 (Conv3D)          (None, 3, 15, 15, 128)    221312
#
#
#
#  activation_38 (Activation)  (None, 3, 15, 15, 128)    0
#
#
#
#  batch_normalization_33 (Bat  (None, 3, 15, 15, 128)   512
#
#  chNormalization)
#
#
#
#  max_pooling3d_23 (MaxPoolin  (None, 1, 7, 7, 128)     0
#
#  g3D)
#
#
#
#  flatten_5 (Flatten)         (None, 6272)              0
#
#
#
#  dense_15 (Dense)            (None, 256)               1605888
#
#
#
#  activation_39 (Activation)  (None, 256)               0
#
#
#
#  batch_normalization_34 (Bat  (None, 256)              1024
#
#  chNormalization)
#
#
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#
#
#  dense_16 (Dense)            (None, 128)               32896
#
#
#
#  activation_40 (Activation)  (None, 128)               0
#
#
#
#  batch_normalization_35 (Bat  (None, 128)              512
#
#  chNormalization)
#
#
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#
#
#  dense_17 (Dense)            (None, 5)                 645
#
#
#
#  activation_41 (Activation)  (None, 5)                 0
#
#
#
# =================================================================
#
# Total params: 1,938,469
#
# Trainable params: 1,937,221
#
# Non-trainable params: 1,248
#
# _________________________________________________________________
#
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_9")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/15
#
# 133/133 [==============================] - ETA: 0s - loss: 1.7426 - categorical_accuracy: 0.3575
#
# Epoch 00001: val_loss improved from inf to 9.84336, saving model to model_conv3D_9_2023-08-2907_28_23.340432/model-00001-1.74264-0.35747-9.84336-0.15000.h5
#
# 133/133 [==============================] - 166s 1s/step - loss: 1.7426 - categorical_accuracy: 0.3575 - val_loss: 9.8434 - val_categorical_accuracy: 0.1500 - lr: 0.0010
#
# Epoch 2/15
#
# 133/133 [==============================] - ETA: 0s - loss: 1.4055 - categorical_accuracy: 0.4449
#
# Epoch 00002: val_loss improved from 9.84336 to 3.31989, saving model to model_conv3D_9_2023-08-2907_28_23.340432/model-00002-1.40553-0.44495-3.31989-0.27000.h5
#
# 133/133 [==============================] - 164s 1s/step - loss: 1.4055 - categorical_accuracy: 0.4449 - val_loss: 3.3199 - val_categorical_accuracy: 0.2700 - lr: 0.0010
#
# Epoch 3/15
#
# 133/133 [==============================] - ETA: 0s - loss: 1.3764 - categorical_accuracy: 0.4615
#
# Epoch 00003: val_loss improved from 3.31989 to 1.45191, saving model to model_conv3D_9_2023-08-2907_28_23.340432/model-00003-1.37643-0.46154-1.45191-0.45000.h5
#
# 133/133 [==============================] - 163s 1s/step - loss: 1.3764 - categorical_accuracy: 0.4615 - val_loss: 1.4519 - val_categorical_accuracy: 0.4500 - lr: 0.0010
#
# Epoch 4/15
#
# 133/133 [==============================] - ETA: 0s - loss: 1.2662 - categorical_accuracy: 0.5098
#
# Epoch 00004: val_loss did not improve from 1.45191
#
# 133/133 [==============================] - 162s 1s/step - loss: 1.2662 - categorical_accuracy: 0.5098 - val_loss: 3.5605 - val_categorical_accuracy: 0.1800 - lr: 0.0010
#
# Epoch 5/15
#
# 133/133 [==============================] - ETA: 0s - loss: 1.1678 - categorical_accuracy: 0.5686
#
# Epoch 00005: val_loss did not improve from 1.45191
#
# 133/133 [==============================] - 163s 1s/step - loss: 1.1678 - categorical_accuracy: 0.5686 - val_loss: 4.8551 - val_categorical_accuracy: 0.2500 - lr: 0.0010
#
# Epoch 6/15
#
# 133/133 [==============================] - ETA: 0s - loss: 1.0812 - categorical_accuracy: 0.5958
#
# Epoch 00006: val_loss did not improve from 1.45191
#
#
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# 133/133 [==============================] - 167s 1s/step - loss: 1.0812 - categorical_accuracy: 0.5958 - val_loss: 1.9101 - val_categorical_accuracy: 0.5100 - lr: 0.0010
#
# Epoch 7/15
#
# 133/133 [==============================] - ETA: 0s - loss: 0.8636 - categorical_accuracy: 0.6727
#
# Epoch 00007: val_loss improved from 1.45191 to 0.96665, saving model to model_conv3D_9_2023-08-2907_28_23.340432/model-00007-0.86359-0.67270-0.96665-0.62000.h5
#
# 133/133 [==============================] - 168s 1s/step - loss: 0.8636 - categorical_accuracy: 0.6727 - val_loss: 0.9667 - val_categorical_accuracy: 0.6200 - lr: 1.0000e-04
#
# Epoch 8/15
#
# 133/133 [==============================] - ETA: 0s - loss: 0.8175 - categorical_accuracy: 0.6621
#
# Epoch 00008: val_loss improved from 0.96665 to 0.59153, saving model to model_conv3D_9_2023-08-2907_28_23.340432/model-00008-0.81748-0.66214-0.59153-0.81000.h5
#
# 133/133 [==============================] - 168s 1s/step - loss: 0.8175 - categorical_accuracy: 0.6621 - val_loss: 0.5915 - val_categorical_accuracy: 0.8100 - lr: 1.0000e-04
#
# Epoch 9/15
#
# 133/133 [==============================] - ETA: 0s - loss: 0.8442 - categorical_accuracy: 0.6742
#
# Epoch 00009: val_loss did not improve from 0.59153
#
# 133/133 [==============================] - 171s 1s/step - loss: 0.8442 - categorical_accuracy: 0.6742 - val_loss: 0.6565 - val_categorical_accuracy: 0.7400 - lr: 1.0000e-04
#
# Epoch 10/15
#
# 133/133 [==============================] - ETA: 0s - loss: 0.7705 - categorical_accuracy: 0.6968
#
# Epoch 00010: val_loss did not improve from 0.59153
#
# 133/133 [==============================] - 162s 1s/step - loss: 0.7705 - categorical_accuracy: 0.6968 - val_loss: 0.6175 - val_categorical_accuracy: 0.8000 - lr: 1.0000e-04
#
# Epoch 11/15
#
# 133/133 [==============================] - ETA: 0s - loss: 0.7539 - categorical_accuracy: 0.7074
#
# Epoch 00011: val_loss did not improve from 0.59153
#
#
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# 133/133 [==============================] - 160s 1s/step - loss: 0.7539 - categorical_accuracy: 0.7074 - val_loss: 0.5951 - val_categorical_accuracy: 0.7500 - lr: 1.0000e-04
#
# Epoch 12/15
#
# 133/133 [==============================] - ETA: 0s - loss: 0.7216 - categorical_accuracy: 0.7270
#
# Epoch 00012: val_loss improved from 0.59153 to 0.44703, saving model to model_conv3D_9_2023-08-2907_28_23.340432/model-00012-0.72157-0.72700-0.44703-0.86000.h5
#
# 133/133 [==============================] - 159s 1s/step - loss: 0.7216 - categorical_accuracy: 0.7270 - val_loss: 0.4470 - val_categorical_accuracy: 0.8600 - lr: 1.0000e-04
#
# Epoch 13/15
#
# 133/133 [==============================] - ETA: 0s - loss: 0.7623 - categorical_accuracy: 0.7149
#
# Epoch 00013: val_loss did not improve from 0.44703
#
# 133/133 [==============================] - 162s 1s/step - loss: 0.7623 - categorical_accuracy: 0.7149 - val_loss: 0.4496 - val_categorical_accuracy: 0.8700 - lr: 1.0000e-04
#
# Epoch 14/15
#
# 133/133 [==============================] - ETA: 0s - loss: 0.6455 - categorical_accuracy: 0.7496
#
# Epoch 00014: val_loss did not improve from 0.44703
#
# 133/133 [==============================] - 160s 1s/step - loss: 0.6455 - categorical_accuracy: 0.7496 - val_loss: 1.1574 - val_categorical_accuracy: 0.6500 - lr: 1.0000e-04
#
# Epoch 15/15
#
# 133/133 [==============================] - ETA: 0s - loss: 0.6610 - categorical_accuracy: 0.7466
#
# Epoch 00015: val_loss did not improve from 0.44703
#
# 133/133 [==============================] - 158s 1s/step - loss: 0.6610 - categorical_accuracy: 0.7466 - val_loss: 0.4644 - val_categorical_accuracy: 0.8200 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# ### TRANSFER LEARNING - MobileNet Conv2d + GRU

# %%
from keras.applications import mobilenet

def mobilenet_RNN(fine_tune=False, gru=False, lstm_gru_cells=128, dense_nodes=128, dropout=0.25, num_images=20, height=120, width=120):

    mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)
    print("Number of layers in the pretrained mobilenet model: ", len(mobilenet_transfer.layers))

    if (fine_tune):
        # Fine-tune from this layer onwards
        fine_tune_at = 50
        # Freeze all the layers before the `fine_tune_at` layer
        for layer in mobilenet_transfer.layers[:fine_tune_at]:
            layer.trainable = False

    model = Sequential()
    model.add(TimeDistributed(mobilenet_transfer,input_shape=(num_images, height, width, 3)))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Flatten()))
    if (gru):
        model.add(GRU(lstm_gru_cells))
    else:
        model.add(LSTM(lstm_gru_cells))
    model.add(Dropout(dropout))
    model.add(Dense(dense_nodes, activation='relu'))
    model.add(Dropout(dropout))
    model.add(Dense(num_classes, activation='softmax'))

    opt = tf.keras.optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    return model

# %% [markdown]
# #### Model 8: Mobilenet (re train all weights) + GRU (128 cells) + 128 dense nodes

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(num_images=num_frames, gru=True)
print (model.summary())
# Out:
# # epochs = 20
#
# # batch size = 10
#
# # num frames per video = 20
#
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#
# Number of layers in the pretrained mobilenet model:  86
#
# Model: "sequential_6"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  time_distributed (TimeDistr  (None, 20, 3, 3, 1024)   3228864
#
#  ibuted)
#
#
#
#  time_distributed_1 (TimeDis  (None, 20, 3, 3, 1024)   4096
#
#  tributed)
#
#
#
#  time_distributed_2 (TimeDis  (None, 20, 1, 1, 1024)   0
#
#  tributed)
#
#
#
#  time_distributed_3 (TimeDis  (None, 20, 1024)         0
#
#  tributed)
#
#
#
#  gru (GRU)                   (None, 128)               443136
#
#
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#
#
#  dense_18 (Dense)            (None, 128)               16512
#
#
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#
#
#  dense_19 (Dense)            (None, 5)                 645
#
#
#
# =================================================================
#
# Total params: 3,693,253
#
# Trainable params: 3,669,317
#
# Non-trainable params: 23,936
#
# _________________________________________________________________
#
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_gru")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.8684 - categorical_accuracy: 0.6817
#
# Epoch 00001: val_loss improved from inf to 0.73860, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00001-0.86838-0.68175-0.73860-0.70000.h5
#
# 67/67 [==============================] - 115s 2s/step - loss: 0.8684 - categorical_accuracy: 0.6817 - val_loss: 0.7386 - val_categorical_accuracy: 0.7000 - lr: 0.0010
#
# Epoch 2/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.2497 - categorical_accuracy: 0.9261
#
# Epoch 00002: val_loss improved from 0.73860 to 0.27647, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00002-0.24975-0.92609-0.27647-0.89000.h5
#
# 67/67 [==============================] - 112s 2s/step - loss: 0.2497 - categorical_accuracy: 0.9261 - val_loss: 0.2765 - val_categorical_accuracy: 0.8900 - lr: 0.0010
#
# Epoch 3/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.2176 - categorical_accuracy: 0.9397
#
# Epoch 00003: val_loss improved from 0.27647 to 0.20935, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00003-0.21755-0.93967-0.20935-0.88000.h5
#
# 67/67 [==============================] - 109s 2s/step - loss: 0.2176 - categorical_accuracy: 0.9397 - val_loss: 0.2094 - val_categorical_accuracy: 0.8800 - lr: 0.0010
#
# Epoch 4/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.1917 - categorical_accuracy: 0.9532
#
# Epoch 00004: val_loss did not improve from 0.20935
#
# 67/67 [==============================] - 109s 2s/step - loss: 0.1917 - categorical_accuracy: 0.9532 - val_loss: 0.2642 - val_categorical_accuracy: 0.9200 - lr: 0.0010
#
# Epoch 5/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.1714 - categorical_accuracy: 0.9457
#
# Epoch 00005: val_loss did not improve from 0.20935
#
# 67/67 [==============================] - 111s 2s/step - loss: 0.1714 - categorical_accuracy: 0.9457 - val_loss: 0.2690 - val_categorical_accuracy: 0.9000 - lr: 0.0010
#
# Epoch 6/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.1799 - categorical_accuracy: 0.9532
#
# Epoch 00006: val_loss did not improve from 0.20935
#
#
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# 67/67 [==============================] - 111s 2s/step - loss: 0.1799 - categorical_accuracy: 0.9532 - val_loss: 0.3204 - val_categorical_accuracy: 0.9100 - lr: 0.0010
#
# Epoch 7/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0928 - categorical_accuracy: 0.9789
#
# Epoch 00007: val_loss improved from 0.20935 to 0.06929, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00007-0.09277-0.97888-0.06929-0.98000.h5
#
# 67/67 [==============================] - 109s 2s/step - loss: 0.0928 - categorical_accuracy: 0.9789 - val_loss: 0.0693 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
#
# Epoch 8/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0519 - categorical_accuracy: 0.9834
#
# Epoch 00008: val_loss did not improve from 0.06929
#
# 67/67 [==============================] - 108s 2s/step - loss: 0.0519 - categorical_accuracy: 0.9834 - val_loss: 0.0706 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
#
# Epoch 9/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0252 - categorical_accuracy: 0.9925
#
# Epoch 00009: val_loss did not improve from 0.06929
#
# 67/67 [==============================] - 108s 2s/step - loss: 0.0252 - categorical_accuracy: 0.9925 - val_loss: 0.0946 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
#
# Epoch 10/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0274 - categorical_accuracy: 0.9925
#
# Epoch 00010: val_loss improved from 0.06929 to 0.04789, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00010-0.02742-0.99246-0.04789-0.98000.h5
#
# 67/67 [==============================] - 112s 2s/step - loss: 0.0274 - categorical_accuracy: 0.9925 - val_loss: 0.0479 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
#
# Epoch 11/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0248 - categorical_accuracy: 0.9970
#
# Epoch 00011: val_loss did not improve from 0.04789
#
# 67/67 [==============================] - 114s 2s/step - loss: 0.0248 - categorical_accuracy: 0.9970 - val_loss: 0.0558 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
#
# Epoch 12/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0238 - categorical_accuracy: 0.9940
#
# Epoch 00012: val_loss did not improve from 0.04789
#
# 67/67 [==============================] - 114s 2s/step - loss: 0.0238 - categorical_accuracy: 0.9940 - val_loss: 0.0763 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
#
# Epoch 13/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0166 - categorical_accuracy: 0.9970
#
# Epoch 00013: val_loss did not improve from 0.04789
#
#
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# 67/67 [==============================] - 115s 2s/step - loss: 0.0166 - categorical_accuracy: 0.9970 - val_loss: 0.0737 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
#
# Epoch 14/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0197 - categorical_accuracy: 0.9970
#
# Epoch 00014: val_loss improved from 0.04789 to 0.02212, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00014-0.01965-0.99698-0.02212-1.00000.h5
#
# 67/67 [==============================] - 116s 2s/step - loss: 0.0197 - categorical_accuracy: 0.9970 - val_loss: 0.0221 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
#
# Epoch 15/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0119 - categorical_accuracy: 0.9970
#
# Epoch 00015: val_loss did not improve from 0.02212
#
# 67/67 [==============================] - 120s 2s/step - loss: 0.0119 - categorical_accuracy: 0.9970 - val_loss: 0.0509 - val_categorical_accuracy: 0.9900 - lr: 1.0000e-04
#
# Epoch 16/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0090 - categorical_accuracy: 0.9985
#
# Epoch 00016: val_loss did not improve from 0.02212
#
# 67/67 [==============================] - 116s 2s/step - loss: 0.0090 - categorical_accuracy: 0.9985 - val_loss: 0.0784 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
#
# Epoch 17/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0077 - categorical_accuracy: 0.9985
#
# Epoch 00017: val_loss improved from 0.02212 to 0.01333, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00017-0.00771-0.99849-0.01333-1.00000.h5
#
# 67/67 [==============================] - 120s 2s/step - loss: 0.0077 - categorical_accuracy: 0.9985 - val_loss: 0.0133 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
#
# Epoch 18/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0079 - categorical_accuracy: 0.9970
#
# Epoch 00018: val_loss did not improve from 0.01333
#
# 67/67 [==============================] - 115s 2s/step - loss: 0.0079 - categorical_accuracy: 0.9970 - val_loss: 0.0811 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
#
# Epoch 19/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0079 - categorical_accuracy: 0.9985
#
# Epoch 00019: val_loss did not improve from 0.01333
#
# 67/67 [==============================] - 113s 2s/step - loss: 0.0079 - categorical_accuracy: 0.9985 - val_loss: 0.0460 - val_categorical_accuracy: 0.9900 - lr: 1.0000e-04
#
# Epoch 20/20
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0178 - categorical_accuracy: 0.9970
#
# Epoch 00020: val_loss did not improve from 0.01333
#
# 67/67 [==============================] - 117s 2s/step - loss: 0.0178 - categorical_accuracy: 0.9970 - val_loss: 0.0465 - val_categorical_accuracy: 0.9900 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 9: Mobilenet (re train all weights) + GRU (128 cells) + 128 dense nodes + Random data transformations on training data set

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(gru=True, num_images=num_frames)
print(model.summary())
# Out:
# # epochs = 15
#
# # batch size = 10
#
# # num frames per video = 30
#
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#
# Number of layers in the pretrained mobilenet model:  86
#
# Model: "sequential_7"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  time_distributed_4 (TimeDis  (None, 30, 3, 3, 1024)   3228864
#
#  tributed)
#
#
#
#  time_distributed_5 (TimeDis  (None, 30, 3, 3, 1024)   4096
#
#  tributed)
#
#
#
#  time_distributed_6 (TimeDis  (None, 30, 1, 1, 1024)   0
#
#  tributed)
#
#
#
#  time_distributed_7 (TimeDis  (None, 30, 1024)         0
#
#  tributed)
#
#
#
#  gru_1 (GRU)                 (None, 128)               443136
#
#
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#
#
#  dense_20 (Dense)            (None, 128)               16512
#
#
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#
#
#  dense_21 (Dense)            (None, 5)                 645
#
#
#
# =================================================================
#
# Total params: 3,693,253
#
# Trainable params: 3,669,317
#
# Non-trainable params: 23,936
#
# _________________________________________________________________
#
# None

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_gru")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=True, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.9975 - categorical_accuracy: 0.6154
#
# Epoch 00001: val_loss improved from inf to 0.75179, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00001-0.99746-0.61538-0.75179-0.73000.h5
#
# 67/67 [==============================] - 198s 3s/step - loss: 0.9975 - categorical_accuracy: 0.6154 - val_loss: 0.7518 - val_categorical_accuracy: 0.7300 - lr: 0.0010
#
# Epoch 2/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.3599 - categorical_accuracy: 0.8824
#
# Epoch 00002: val_loss improved from 0.75179 to 0.40959, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00002-0.35987-0.88235-0.40959-0.83000.h5
#
# 67/67 [==============================] - 188s 3s/step - loss: 0.3599 - categorical_accuracy: 0.8824 - val_loss: 0.4096 - val_categorical_accuracy: 0.8300 - lr: 0.0010
#
# Epoch 3/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.3315 - categorical_accuracy: 0.9005
#
# Epoch 00003: val_loss did not improve from 0.40959
#
# 67/67 [==============================] - 190s 3s/step - loss: 0.3315 - categorical_accuracy: 0.9005 - val_loss: 0.5426 - val_categorical_accuracy: 0.8200 - lr: 0.0010
#
# Epoch 4/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.3161 - categorical_accuracy: 0.9020
#
# Epoch 00004: val_loss did not improve from 0.40959
#
# 67/67 [==============================] - 184s 3s/step - loss: 0.3161 - categorical_accuracy: 0.9020 - val_loss: 0.8781 - val_categorical_accuracy: 0.7400 - lr: 0.0010
#
# Epoch 5/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.2167 - categorical_accuracy: 0.9427
#
# Epoch 00005: val_loss improved from 0.40959 to 0.21287, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00005-0.21668-0.94268-0.21287-0.91000.h5
#
# 67/67 [==============================] - 188s 3s/step - loss: 0.2167 - categorical_accuracy: 0.9427 - val_loss: 0.2129 - val_categorical_accuracy: 0.9100 - lr: 0.0010
#
# Epoch 6/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.1647 - categorical_accuracy: 0.9502
#
# Epoch 00006: val_loss improved from 0.21287 to 0.05735, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00006-0.16470-0.95023-0.05735-0.99000.h5
#
# 67/67 [==============================] - 187s 3s/step - loss: 0.1647 - categorical_accuracy: 0.9502 - val_loss: 0.0573 - val_categorical_accuracy: 0.9900 - lr: 0.0010
#
# Epoch 7/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.1132 - categorical_accuracy: 0.9623
#
# Epoch 00007: val_loss did not improve from 0.05735
#
# 67/67 [==============================] - 189s 3s/step - loss: 0.1132 - categorical_accuracy: 0.9623 - val_loss: 0.1777 - val_categorical_accuracy: 0.9400 - lr: 0.0010
#
# Epoch 8/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.1086 - categorical_accuracy: 0.9668
#
# Epoch 00008: val_loss did not improve from 0.05735
#
# 67/67 [==============================] - 188s 3s/step - loss: 0.1086 - categorical_accuracy: 0.9668 - val_loss: 0.2406 - val_categorical_accuracy: 0.9300 - lr: 0.0010
#
# Epoch 9/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.1891 - categorical_accuracy: 0.9472
#
# Epoch 00009: val_loss did not improve from 0.05735
#
#
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# 67/67 [==============================] - 202s 3s/step - loss: 0.1891 - categorical_accuracy: 0.9472 - val_loss: 0.1004 - val_categorical_accuracy: 0.9800 - lr: 0.0010
#
# Epoch 10/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0629 - categorical_accuracy: 0.9864
#
# Epoch 00010: val_loss did not improve from 0.05735
#
# 67/67 [==============================] - 208s 3s/step - loss: 0.0629 - categorical_accuracy: 0.9864 - val_loss: 0.0777 - val_categorical_accuracy: 0.9900 - lr: 1.0000e-04
#
# Epoch 11/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0649 - categorical_accuracy: 0.9804
#
# Epoch 00011: val_loss did not improve from 0.05735
#
# 67/67 [==============================] - 205s 3s/step - loss: 0.0649 - categorical_accuracy: 0.9804 - val_loss: 0.0597 - val_categorical_accuracy: 0.9900 - lr: 1.0000e-04
#
# Epoch 12/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0550 - categorical_accuracy: 0.9834
#
# Epoch 00012: val_loss did not improve from 0.05735
#
#
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# 67/67 [==============================] - 208s 3s/step - loss: 0.0550 - categorical_accuracy: 0.9834 - val_loss: 0.0639 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
#
# Epoch 13/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0316 - categorical_accuracy: 0.9955
#
# Epoch 00013: val_loss did not improve from 0.05735
#
# 67/67 [==============================] - 198s 3s/step - loss: 0.0316 - categorical_accuracy: 0.9955 - val_loss: 0.0947 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
#
# Epoch 14/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0390 - categorical_accuracy: 0.9894
#
# Epoch 00014: val_loss improved from 0.05735 to 0.05449, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00014-0.03903-0.98944-0.05449-0.99000.h5
#
# 67/67 [==============================] - 187s 3s/step - loss: 0.0390 - categorical_accuracy: 0.9894 - val_loss: 0.0545 - val_categorical_accuracy: 0.9900 - lr: 1.0000e-04
#
# Epoch 15/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0226 - categorical_accuracy: 0.9925
#
# Epoch 00015: val_loss improved from 0.05449 to 0.01405, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00015-0.02262-0.99246-0.01405-1.00000.h5
#
# 67/67 [==============================] - 187s 3s/step - loss: 0.0226 - categorical_accuracy: 0.9925 - val_loss: 0.0140 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 10: Mobilenet (re train all wieghts) + LSTM (128 cells) + 128 dense nodes

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(fine_tune=False, gru=False, num_images=num_frames)
print(model.summary())
# Out:
# # epochs = 15
#
# # batch size = 10
#
# # num frames per video = 20
#
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#
# Number of layers in the pretrained mobilenet model:  86
#
# Model: "sequential_9"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  time_distributed_12 (TimeDi  (None, 20, 3, 3, 1024)   3228864
#
#  stributed)
#
#
#
#  time_distributed_13 (TimeDi  (None, 20, 3, 3, 1024)   4096
#
#  stributed)
#
#
#
#  time_distributed_14 (TimeDi  (None, 20, 1, 1, 1024)   0
#
#  stributed)
#
#
#
#  time_distributed_15 (TimeDi  (None, 20, 1024)         0
#
#  stributed)
#
#
#
#  lstm_1 (LSTM)               (None, 128)               590336
#
#
#
#  dropout_18 (Dropout)        (None, 128)               0
#
#
#
#  dense_24 (Dense)            (None, 128)               16512
#
#
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#
#
#  dense_25 (Dense)            (None, 5)                 645
#
#
#
# =================================================================
#
# Total params: 3,840,453
#
# Trainable params: 3,816,517
#
# Non-trainable params: 23,936
#
# _________________________________________________________________
#
# None

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_lstm")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/15
#
# 67/67 [==============================] - ETA: 0s - loss: 1.1077 - categorical_accuracy: 0.5234
#
# Epoch 00001: val_loss improved from inf to 0.67545, saving model to model_retrain_mobilenet_lstm_2023-08-2907_28_23.340432/model-00001-1.10770-0.52338-0.67545-0.78000.h5
#
# 67/67 [==============================] - 115s 2s/step - loss: 1.1077 - categorical_accuracy: 0.5234 - val_loss: 0.6754 - val_categorical_accuracy: 0.7800 - lr: 0.0010
#
# Epoch 2/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.4588 - categorical_accuracy: 0.8507
#
# Epoch 00002: val_loss improved from 0.67545 to 0.29834, saving model to model_retrain_mobilenet_lstm_2023-08-2907_28_23.340432/model-00002-0.45876-0.85068-0.29834-0.89000.h5
#
# 67/67 [==============================] - 110s 2s/step - loss: 0.4588 - categorical_accuracy: 0.8507 - val_loss: 0.2983 - val_categorical_accuracy: 0.8900 - lr: 0.0010
#
# Epoch 3/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.3538 - categorical_accuracy: 0.8944
#
# Epoch 00003: val_loss did not improve from 0.29834
#
# 67/67 [==============================] - 112s 2s/step - loss: 0.3538 - categorical_accuracy: 0.8944 - val_loss: 0.4512 - val_categorical_accuracy: 0.8500 - lr: 0.0010
#
# Epoch 4/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.2895 - categorical_accuracy: 0.9125
#
# Epoch 00004: val_loss improved from 0.29834 to 0.10777, saving model to model_retrain_mobilenet_lstm_2023-08-2907_28_23.340432/model-00004-0.28946-0.91252-0.10777-0.96000.h5
#
# 67/67 [==============================] - 115s 2s/step - loss: 0.2895 - categorical_accuracy: 0.9125 - val_loss: 0.1078 - val_categorical_accuracy: 0.9600 - lr: 0.0010
#
# Epoch 5/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.2299 - categorical_accuracy: 0.9291
#
# Epoch 00005: val_loss did not improve from 0.10777
#
# 67/67 [==============================] - 114s 2s/step - loss: 0.2299 - categorical_accuracy: 0.9291 - val_loss: 0.3219 - val_categorical_accuracy: 0.8900 - lr: 0.0010
#
# Epoch 6/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.1670 - categorical_accuracy: 0.9412
#
# Epoch 00006: val_loss did not improve from 0.10777
#
# 67/67 [==============================] - 107s 2s/step - loss: 0.1670 - categorical_accuracy: 0.9412 - val_loss: 0.1642 - val_categorical_accuracy: 0.9700 - lr: 0.0010
#
# Epoch 7/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.2097 - categorical_accuracy: 0.9367
#
# Epoch 00007: val_loss did not improve from 0.10777
#
#
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# 67/67 [==============================] - 109s 2s/step - loss: 0.2097 - categorical_accuracy: 0.9367 - val_loss: 0.1145 - val_categorical_accuracy: 0.9400 - lr: 0.0010
#
# Epoch 8/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.1170 - categorical_accuracy: 0.9668
#
# Epoch 00008: val_loss improved from 0.10777 to 0.09610, saving model to model_retrain_mobilenet_lstm_2023-08-2907_28_23.340432/model-00008-0.11704-0.96682-0.09610-0.96000.h5
#
# 67/67 [==============================] - 109s 2s/step - loss: 0.1170 - categorical_accuracy: 0.9668 - val_loss: 0.0961 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
#
# Epoch 9/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.1052 - categorical_accuracy: 0.9653
#
# Epoch 00009: val_loss did not improve from 0.09610
#
# 67/67 [==============================] - 112s 2s/step - loss: 0.1052 - categorical_accuracy: 0.9653 - val_loss: 0.1264 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
#
# Epoch 10/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0647 - categorical_accuracy: 0.9864
#
# Epoch 00010: val_loss improved from 0.09610 to 0.06719, saving model to model_retrain_mobilenet_lstm_2023-08-2907_28_23.340432/model-00010-0.06475-0.98643-0.06719-0.96000.h5
#
# 67/67 [==============================] - 111s 2s/step - loss: 0.0647 - categorical_accuracy: 0.9864 - val_loss: 0.0672 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
#
# Epoch 11/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0935 - categorical_accuracy: 0.9804
#
# Epoch 00011: val_loss did not improve from 0.06719
#
# 67/67 [==============================] - 109s 2s/step - loss: 0.0935 - categorical_accuracy: 0.9804 - val_loss: 0.0805 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
#
# Epoch 12/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0723 - categorical_accuracy: 0.9819
#
# Epoch 00012: val_loss improved from 0.06719 to 0.06227, saving model to model_retrain_mobilenet_lstm_2023-08-2907_28_23.340432/model-00012-0.07229-0.98190-0.06227-0.97000.h5
#
# 67/67 [==============================] - 108s 2s/step - loss: 0.0723 - categorical_accuracy: 0.9819 - val_loss: 0.0623 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
#
# Epoch 13/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0564 - categorical_accuracy: 0.9849
#
# Epoch 00013: val_loss improved from 0.06227 to 0.05053, saving model to model_retrain_mobilenet_lstm_2023-08-2907_28_23.340432/model-00013-0.05637-0.98492-0.05053-0.97000.h5
#
# 67/67 [==============================] - 107s 2s/step - loss: 0.0564 - categorical_accuracy: 0.9849 - val_loss: 0.0505 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
#
# Epoch 14/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0280 - categorical_accuracy: 0.9940
#
# Epoch 00014: val_loss did not improve from 0.05053
#
# 67/67 [==============================] - 111s 2s/step - loss: 0.0280 - categorical_accuracy: 0.9940 - val_loss: 0.0532 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
#
# Epoch 15/15
#
# 67/67 [==============================] - ETA: 0s - loss: 0.0242 - categorical_accuracy: 0.9925
#
# Epoch 00015: val_loss improved from 0.05053 to 0.01912, saving model to model_retrain_mobilenet_lstm_2023-08-2907_28_23.340432/model-00015-0.02421-0.99246-0.01912-1.00000.h5
#
# 67/67 [==============================] - 108s 2s/step - loss: 0.0242 - categorical_accuracy: 0.9925 - val_loss: 0.0191 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])
